# %% [markdown]
# # exp065

# %% [markdown]
# exp064の特徴量削減ver

# %%
import os
import sys
import traceback
import gc
import time
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from collections import defaultdict

import pandas as pd
import numpy as np
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.model_selection import GroupKFold
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import itertools

import warnings
warnings.simplefilter('ignore')

# %%
@dataclass
class Cfg:
    mode = "local_cv" # "local_cv" or "kaggle_inf" 
    exp_name = "exp065"
    input_dir = "/mnt/predict-student-performance-from-game-play/input/"
    output_dir = "/mnt/predict-student-performance-from-game-play/output/"
    prep_dir = "/mnt/predict-student-performance-from-game-play/prep/"
    seed = 42
    n_splits = 5
    best_threshold = 0.630 # local_cvの結果を入れる
    feature_select = True # 特徴量削減するか
    n_features = 2000 # 特徴量削減の数
    base_exp = "exp064" # 特徴量重要度を使う元のexp
cfg = Cfg()

if cfg.mode == "local_cv":
    os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
    os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)

elif cfg.mode == "kaggle_inf":
    import jo_wilder_310

# %%
params = {
    'objective': 'binary', 
    'boosting': 'gbdt', 
    'learning_rate': 0.01, 
    'metric': 'binary_logloss', 
    'seed': cfg.seed, 
    'feature_pre_filter': False, 
    'lambda_l1': 4.134488140102331, 
    'lambda_l2': 0.007775200046481757, 
    'num_leaves': 75, 
    'feature_fraction': 0.5, 
    'bagging_fraction': 0.7036110805680353, 
    'bagging_freq': 3, 
    'min_data_in_leaf': 50, 
    'min_child_samples': 100
}

# %%
level_group_list = ['0-4', '5-12', '13-22']
level_group_map = {
    "q1":"0-4", "q2":"0-4", "q3":"0-4",
    "q4":"5-12", "q5":"5-12", "q6":"5-12", "q7":"5-12", "q8":"5-12", "q9":"5-12", "q10":"5-12", "q11":"5-12", "q12":"5-12", "q13":"5-12",
    "q14":"13-22", "q15":"13-22", "q16":"13-22", "q17":"13-22", "q18":"13-22"  
}

# %%
if cfg.mode == "local_cv":
    with open(cfg.prep_dir + 'cat_col_lists.pkl', 'rb') as f:
        cat_col_lists = pickle.load(f) 

elif cfg.mode == "kaggle_inf":
    with open("/kaggle/input/psp-cat-col-lists/cat_col_lists.pkl", 'rb') as f:
        cat_col_lists = pickle.load(f)

# %%
# 使用する特徴量の抽出
features_dict = {} # 各level_groupごと使用する特徴量
need_create_features = None # 生成する必要がある特徴量一覧
if cfg.feature_select:
    if cfg.mode == "local_cv":
        features_dict["0-4"] = pd.read_csv(cfg.output_dir + f"{cfg.base_exp}/fi_0-4.csv").head(cfg.n_features)["feature"].tolist()
        features_dict["5-12"] = pd.read_csv(cfg.output_dir + f"{cfg.base_exp}/fi_5-12.csv").head(cfg.n_features)["feature"].tolist()
        features_dict["13-22"] = pd.read_csv(cfg.output_dir + f"{cfg.base_exp}/fi_13-22.csv").head(cfg.n_features)["feature"].tolist()
    elif cfg.mode == "kaggle_inf":
        features_dict["0-4"] = pd.read_csv(f"/kaggle/input/jo-wilder-{cfg.exp_name}/fi_0-4.csv")["feature"].tolist()
        features_dict["5-12"] = pd.read_csv(f"/kaggle/input/jo-wilder-{cfg.exp_name}/fi_5-12.csv")["feature"].tolist()
        features_dict["13-22"] = pd.read_csv(f"/kaggle/input/jo-wilder-{cfg.exp_name}/fi_13-22.csv")["feature"].tolist()

    need_create_features = features_dict["0-4"] + features_dict["5-12"] + features_dict["13-22"]
    need_create_features = list(set(need_create_features))

# %%
def transform_labels_df_train(labels_):
    """
    labelsデータを整形する
    """
    labels = labels_.copy()
    labels["question"] = labels["session_id"].apply(lambda x: x.split("_")[1].replace("q", "")).astype(int)
    labels["session_id"] = labels["session_id"].apply(lambda x: x.split("_")[0]).astype(int)

    # trainの特徴量と結合するためにquestionに対応するlabel_groupを列として設けておく
    labels["level_group"] = ""
    labels.loc[labels["question"]<=3, "level_group"] = "0-4"
    labels.loc[(labels["question"]>=4)&(labels["question"]<=13), "level_group"] = "5-12"
    labels.loc[labels["question"]>=14, "level_group"] = "13-22"

    return labels


def transform_labels_df_inf(labels_):
    """
    labelsデータを整形する
    """
    labels = labels_.copy()
    labels["question"] = labels["session_id"].apply(lambda x: x.split("_")[1].replace("q", "")).astype(int)
    labels["session_id"] = labels["session_id"].apply(lambda x: x.split("_")[0]).astype(int)

    return labels

# %%
class FeaturesTrain:
    def __init__(self, sessions_df, labels):
        self.sessions_df = sessions_df.sort_values(["session_id", "level_group", "elapsed_time"], ignore_index=True)
        self.features = self.sessions_df[["session_id", "level_group"]].drop_duplicates().copy()
        self.result = labels
        self.group = sessions_df["level_group"].values[0]

    def _prep(self):
        self.sessions_df["time_diff"] = self.sessions_df["elapsed_time"] - self.sessions_df.groupby(["session_id", "level_group"])["elapsed_time"].shift(1)

    def _total_record_cnt(self):
        """level_groupごとのレコード数
        """
        add_features = self.sessions_df.groupby(["session_id", "level_group"])["index"].count().reset_index().rename(columns={"index":f"{self.group}_record_cnt"})
        self.features = self.features.merge(add_features, on=["session_id", "level_group"], how="left")

    def _group_elapsed_time(self):
        """level_groupごと、epapsed_timeのmax - min（経過時間）
        """
        add_features = self.sessions_df.groupby(["session_id", "level_group"])["elapsed_time"].agg([max,min]).reset_index()
        add_features[f"{self.group}_group_elapsed_time"] = add_features["max"] - add_features["min"]
        add_features[f"{self.group}_group_elapsed_time"] = add_features[f"{self.group}_group_elapsed_time"].astype(np.float32)
        add_features = add_features[["session_id", "level_group", f"{self.group}_group_elapsed_time"]].copy()
        self.features = self.features.merge(add_features, on=["session_id", "level_group"], how="left")

    def _cat_record_cnt(self, cat_col):
        """level_groupごと、各{cat}のレコード数
        """
        cat_list = cat_col_lists[self.group][cat_col]
        add_features = self.sessions_df.groupby(["session_id", "level_group", cat_col])["index"].count().reset_index().rename(columns={"index":"cnt"})
        for cat in cat_list:
            feat_name = f"{self.group}_{cat_col}_{str(cat)}_record_cnt"
            tmp = add_features[add_features[cat_col]==cat][["session_id", "level_group", "cnt"]].copy()
            if len(tmp) > 0:
                tmp = tmp.rename(columns={"cnt": feat_name})
                self.features = self.features.merge(tmp, on=["session_id", "level_group"], how="left")
                self.features[feat_name] = self.features[feat_name].fillna(0)
            else:
                self.features[feat_name] = 0

    def _cat_col_nunique(self, cat_col):
        """level_groupごと、[col]のユニーク数
        """
        add_features = self.sessions_df.dropna(subset=[cat_col]).drop_duplicates(["session_id", "level_group", cat_col])
        add_features = add_features.groupby(["session_id", "level_group"])["index"].count().reset_index().rename(columns={"index":f"{self.group}_{cat_col}_nunique"})
        self.features = self.features.merge(add_features, on=["session_id", "level_group"], how="left")        

    def _agg_features(self, val_cols, aggs):
        new_cols = [f"{self.group}_{v}_{a}" for v,a in itertools.product(val_cols, aggs)]
        add_features = self.sessions_df.groupby(["session_id", "level_group"])[val_cols].agg(aggs).reset_index()
        add_features.columns = ["session_id", "level_group"] + new_cols
        add_features[new_cols] = add_features[new_cols].astype(np.float32)
        self.features = self.features.merge(add_features, on=["session_id", "level_group"], how="left")

    def _cat_agg_features(self, val_cols, aggs, cat_col, not_use_cats=None):
        add_features = self.sessions_df.groupby(["session_id", "level_group", cat_col])[val_cols].agg(aggs).reset_index()

        if not_use_cats is not None:
            cat_list = [c for c in cat_col_lists[self.group][cat_col] if c not in not_use_cats]
        else:
            cat_list = cat_col_lists[self.group][cat_col]

        for cat in cat_list:
            new_cols = [f"{self.group}_{cat_col}_{cat}_{v}_{a}" for v,a in itertools.product(val_cols, aggs)]
            tmp = add_features[add_features[cat_col]==cat].copy()
            if len(tmp) > 0:
                tmp.columns = ["session_id", "level_group", cat_col] + new_cols
                tmp = tmp.drop(columns=[cat_col])
                self.features = self.features.merge(tmp, on=["session_id", "level_group"], how="left")
                self.features[new_cols] = self.features[new_cols].fillna(-1)
            else:
                self.features[new_cols] = -1
            self.features[new_cols] = self.features[new_cols].astype(np.float32)

    def get_train(self):
        self._prep()
        self._total_record_cnt()
        self._group_elapsed_time()
        self._cat_record_cnt("event_name")
        self._cat_record_cnt("name")
        self._cat_record_cnt("page")
        self._cat_record_cnt("level")
        self._cat_record_cnt("room_fqid")
        self._cat_record_cnt("fqid")
        self._cat_record_cnt("text_fqid")
        self._cat_col_nunique("text")
        self._cat_col_nunique("text_fqid")
        self._cat_col_nunique("room_fqid")
        self._cat_col_nunique("fqid")

        self._agg_features(val_cols=["room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y"], 
                           aggs=["mean"])
        self._agg_features(val_cols=["time_diff", "hover_duration"], 
                           aggs=["mean", "max", "min", "std", "sum"])
        
        self._agg_features(val_cols=["elapsed_time", "index"], 
                           aggs=["max", "min"])

        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="event_name")
        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="room_fqid")
        
        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="fqid")
        self._cat_agg_features(val_cols=["elapsed_time"],
                               aggs=["max", "min"],
                               cat_col="fqid")

        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="text_fqid")
        self._cat_agg_features(val_cols=["elapsed_time", "index"],
                               aggs=["max", "min"],
                               cat_col="text_fqid")
        
        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="level")
        self._cat_agg_features(val_cols=["elapsed_time", "index"],
                               aggs=["max", "min"],
                               cat_col="level")
        
        self._cat_agg_features(val_cols=["room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y"],
                               aggs=["mean"],
                               cat_col="event_name",
                               not_use_cats=['checkpoint', 'map_hover', 'object_hover'])        
        self._cat_agg_features(val_cols=["room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y"],
                               aggs=["mean"],
                               cat_col="name")
        
        self.result = self.result.merge(self.features, on=["session_id", "level_group"], how="left")
        return self.result

# %%
class FeaturesInf:
    def __init__(self, sessions_df, labels):
        self.sessions_df = sessions_df.sort_values(["elapsed_time"], ignore_index=True)
        self.result = labels
        self.group = sessions_df["level_group"].values[0]
        self.use_cols = [
            "elapsed_time", "event_name", "name", "level", "page", "index",
            "room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y",
            "hover_duration", "text", "fqid", "room_fqid", "text_fqid"
        ]

    def _prep(self):
        # dataframeの各列をnumpy arrayで保持
        self.sessions = {}
        for c in self.use_cols:
            self.sessions[c] = self.sessions_df[c].values
        self.sessions["time_diff"] = self.sessions["elapsed_time"] - self.sessions_df["elapsed_time"].shift(1).values

    def _total_record_cnt(self):
        """level_groupごとのレコード数
        """
        feat_name = f"{self.group}_record_cnt"
        if cfg.feature_select & (feat_name not in need_create_features):
            pass
        else:
            add_feature = len(self.sessions["elapsed_time"])
            self.result[feat_name] = add_feature

    def _group_elapsed_time(self):
        """level_groupごと、epapsed_timeのmax - min（経過時間）
        """
        feat_name = f"{self.group}_group_elapsed_time"
        if cfg.feature_select & (feat_name not in need_create_features):
            pass
        else:
            add_feature = np.max(self.sessions["elapsed_time"]) - np.min(self.sessions["elapsed_time"])
            self.result[feat_name] = np.float32(add_feature)

    def _cat_record_cnt(self, cat_col):
        """level_groupごと、各{cat}のレコード数
        """
        cat_list = cat_col_lists[self.group][cat_col]
        for cat in cat_list:
            feat_name = f"{self.group}_{cat_col}_{str(cat)}_record_cnt"
            if cfg.feature_select & (feat_name not in need_create_features):
                pass
            else:
                add_feature = (self.sessions[cat_col] == cat).astype(int).sum()
                self.result[feat_name] = add_feature

    def _cat_col_nunique(self, cat_col):
        """level_groupごと、[col]のユニーク数
        """
        feat_name = f"{self.group}_{cat_col}_nunique"
        if cfg.feature_select & (feat_name not in need_create_features):
            pass
        else:
            self.result[feat_name] = self.sessions_df[cat_col].dropna().nunique()       

    def _agg_features(self, val_cols, aggs):
        for val_col, agg in itertools.product(val_cols, aggs):
            feat_name = f"{self.group}_{val_col}_{agg}"
            if agg == "mean":
                add_feature = np.nanmean(self.sessions[val_col])
            elif agg == "max":
                add_feature = np.nanmax(self.sessions[val_col])
            elif agg == "min":
                add_feature = np.nanmin(self.sessions[val_col])
            elif agg == "std":
                add_feature = np.nanstd(self.sessions[val_col], ddof=1)
            elif agg == "sum":
                add_feature = np.nansum(self.sessions[val_col])
            self.result[feat_name] = np.float32(add_feature)

    def _cat_agg_features(self, val_cols, aggs, cat_col, not_use_cats=None):
        if not_use_cats is not None:
            cat_list = [c for c in cat_col_lists[self.group][cat_col] if c not in not_use_cats]
        else:
            cat_list = cat_col_lists[self.group][cat_col]

        for cat in cat_list:
            idx = self.sessions[cat_col] == cat
        
            if idx.sum() == 0:
                for val_col, agg in itertools.product(val_cols, aggs):
                    feat_name = f"{self.group}_{cat_col}_{cat}_{val_col}_{agg}"
                    if cfg.feature_select & (feat_name not in need_create_features):
                        pass
                    else:
                        self.result[feat_name] = np.float32(-1)
            else:
                for val_col, agg in itertools.product(val_cols, aggs):
                    feat_name = f"{self.group}_{cat_col}_{cat}_{val_col}_{agg}"
                    if cfg.feature_select & (feat_name not in need_create_features):
                        pass
                    else:
                        tmp = self.sessions[val_col][idx]
                        if agg == "mean":
                            add_feature = np.nanmean(tmp)
                        elif agg == "max":
                            add_feature = np.nanmax(tmp)
                        elif agg == "min":
                            add_feature = np.nanmin(tmp)
                        elif agg == "std":
                            add_feature = np.nanstd(tmp, ddof=1)
                        elif agg == "sum":
                            add_feature = np.nansum(tmp)
                        if np.isnan(add_feature):
                            self.result[feat_name] = np.float32(-1)
                        else:
                            self.result[feat_name] = np.float32(add_feature)

    def get_test(self):
        self._prep()
        self._total_record_cnt()
        self._group_elapsed_time()
        self._cat_record_cnt("event_name")
        self._cat_record_cnt("name")
        self._cat_record_cnt("page")
        self._cat_record_cnt("level")
        self._cat_record_cnt("room_fqid")
        self._cat_record_cnt("fqid")
        self._cat_record_cnt("text_fqid")
        self._cat_col_nunique("text")
        self._cat_col_nunique("text_fqid")
        self._cat_col_nunique("room_fqid")
        self._cat_col_nunique("fqid")

        self._agg_features(val_cols=["room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y"], 
                           aggs=["mean"])
        self._agg_features(val_cols=["time_diff", "hover_duration"], 
                           aggs=["mean", "max", "min", "std", "sum"])

        self._agg_features(val_cols=["elapsed_time", "index"], 
                           aggs=["max", "min"])

        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="event_name")
        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="room_fqid")
        
        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="fqid")
        self._cat_agg_features(val_cols=["elapsed_time"],
                               aggs=["max", "min"],
                               cat_col="fqid")

        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="text_fqid")
        self._cat_agg_features(val_cols=["elapsed_time", "index"],
                               aggs=["max", "min"],
                               cat_col="text_fqid")
        
        self._cat_agg_features(val_cols=["time_diff"],
                               aggs=["mean", "max", "min", "std", "sum"],
                               cat_col="level")
        self._cat_agg_features(val_cols=["elapsed_time", "index"],
                               aggs=["max", "min"],
                               cat_col="level")
        
        self._cat_agg_features(val_cols=["room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y"],
                               aggs=["mean"],
                               cat_col="event_name",
                               not_use_cats=['checkpoint', 'map_hover', 'object_hover'])        
        self._cat_agg_features(val_cols=["room_coor_x", "room_coor_y", "screen_coor_x", "screen_coor_y"],
                               aggs=["mean"],
                               cat_col="name")
        return self.result

# %%
def get_train_dataset(sessions, labels):
    # labelデータの整形
    labels = transform_labels_df_train(labels)

    # 特徴量生成
    feat = FeaturesTrain(sessions, labels)
    train = feat.get_train()
    train["question"] = train["question"].astype("category")

    return train

def get_test_dataset(sessions, labels):
    # labelデータの整形
    labels = transform_labels_df_inf(labels)

    # 特徴量生成
    feat = FeaturesInf(sessions, labels)
    test = feat.get_test()
    test["question"] = test["question"].astype("category")

    return test

# %%
def calc_metrics(oof):
    logloss = log_loss(oof["correct"], oof["pred"])

    # find best th
    scores = []; thresholds = []
    best_score = 0; best_threshold = 0

    for threshold in np.arange(0.4,0.81,0.01):
        preds = (oof["pred"].values>threshold).astype(int)
        m = f1_score(oof["correct"].values, preds, average='macro')   
        scores.append(m)
        thresholds.append(threshold)
        if m>best_score:
            best_score = m
            best_threshold = threshold
    print("logloss", format(logloss, ".6f"))
    print("best_score", format(best_score, ".6f"))
    print("best_threshold", format(best_threshold, ".3f"))

    # Q別スコア
    print("---"*10)
    for q in range(18):
        q = q + 1
        preds = (oof[oof["question"]==q]["pred"].values>threshold).astype(int)
        m = f1_score(oof[oof["question"]==q]["correct"].values, preds, average='macro')
        print(f"Q{q} : F1 = {format(m, '.6f')}")
    return best_threshold

# %%
def run_train():
    oofs = []
    prev_features_df = None # 次のlevel_groupで特徴量を使うための保持データ。0-4は前のlevel_groupがないので初期値はNone
    for group in level_group_list:
        print(group)
        # データ読み込み
        train_sessions = pd.read_csv(cfg.prep_dir + f"train{group}.csv")
        labels = pd.read_csv(cfg.prep_dir + f"train_labels{group}.csv")
        train = get_train_dataset(train_sessions, labels)

        # 一つ前のlevel_groupの特徴量を追加
        if prev_features_df is not None:
            train = train.merge(prev_features_df, on=["session_id"], how="left")
        else:
            pass

        # 前のlevel_groupのquestionパートの経過時間特徴量
        if group == "5-12":
            train["0-4_question_duration_time"] = train["5-12_elapsed_time_min"] - train["0-4_elapsed_time_max"]
            train["0-4_question_duration_index"] = train["5-12_index_min"] - train["0-4_index_max"]
        elif group == "13-22":
            train["5-12_question_duration_time"] = train["13-22_elapsed_time_min"] - train["5-12_elapsed_time_max"]
            train["5-12_question_duration_index"] = train["13-22_index_min"] - train["5-12_index_max"]
    
        target = "correct"
        not_use_cols = [target, "session_id", "level_group"]
        features = [c for c in train.columns if c not in not_use_cols]

        # 特徴量選択をする場合、その情報で使用する特徴量を上書き
        if cfg.feature_select:
            features = features_dict[group]

        gkf = GroupKFold(n_splits=cfg.n_splits)
        fis = []
        
        for i, (tr_idx, vl_idx) in enumerate(gkf.split(train[features], train[target], train["session_id"])):
            oof_groups = []
            print(f"fold : {i}")
            tr_x, tr_y = train.iloc[tr_idx][features], train.iloc[tr_idx][target]
            vl_x, vl_y = train.iloc[vl_idx][features], train.iloc[vl_idx][target]
            tr_data = lgb.Dataset(tr_x, label=tr_y)
            vl_data = lgb.Dataset(vl_x, label=vl_y)

            model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                            num_boost_round=20000, early_stopping_rounds=100, verbose_eval=100)
            # モデル出力
            model.save_model(cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_model_{group}_{i}.lgb")
        
            # valid_pred
            oof_fold = train.iloc[vl_idx].copy()
            oof_fold["pred"] = model.predict(vl_x, num_iteration=model.best_iteration)
            oof_groups.append(oof_fold)

            # 特徴量重要度
            fi_fold = pd.DataFrame()
            fi_fold["feature"] = model.feature_name()
            fi_fold["importance"] = model.feature_importance(importance_type="gain")
            fi_fold["fold"] = i
            fis.append(fi_fold)

        fi = pd.concat(fis)    
        fi = fi.groupby("feature")["importance"].mean().reset_index()
        fi = fi.sort_values("importance", ascending=False).reset_index(drop=True)
        fi.to_csv(cfg.output_dir + f"{cfg.exp_name}/fi_{group}.csv", index=False)

        oof_group = pd.concat(oof_groups)
        oofs.append(oof_group)

        # 次のlevel_groupで使う用に特徴量を保持
        prev_features_df = train.groupby("session_id").head(1).drop(columns=["question", "correct", "level_group"])

        # meta_featureの付与
        meta_df = oof_group.groupby("session_id")["pred"].agg(["mean", "max", "min", "std"]).reset_index()
        meta_df = meta_df.rename(columns={"mean":f"{group}_pred_mean", "max":f"{group}_pred_max", "min":f"{group}_pred_min", "std":f"{group}_pred_std"})
        prev_features_df = prev_features_df.merge(meta_df, on="session_id", how="left")

    # cv
    oof = pd.concat(oofs)
    best_threshold = calc_metrics(oof)
    cfg.best_threshold = best_threshold
    oof[["session_id", "question", "pred", "correct"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/oof.csv.gz", compression="gzip", index=False)

# %%
def get_mock_iter_train():
    """trainデータのiter分割を適用したtest_sample
    """
    test = pd.read_csv(cfg.input_dir + "_old/test.csv")
    sub = pd.read_csv(cfg.input_dir + "_old/sample_submission.csv")
    sub["level_group"] = sub["session_level"].apply(lambda x: x.split("_")[-1])
    
    # groupbyでiter作るときにgroup_levelの順番が崩れないように
    test["level_group2"] = test["level_group"].str.replace("13-22", "6")
    sub["level_group2"] = sub["level_group"].str.replace("13-22", "6")

    tests = [df[1].drop(columns=["session_level", "level_group2"]).reset_index(drop=True) for df in test.groupby("level_group2")]
    subs = [df[1].drop(columns=["session_level", "level_group2"]).reset_index(drop=True) for df in sub.groupby("level_group2")]
    return zip(tests, subs)

def get_mock_iter_test():
    """testデータのiter分割を適用したtest_sample
    """
    test = pd.read_csv(cfg.input_dir + "_old/test.csv")
    sub = pd.read_csv(cfg.input_dir + "_old/sample_submission.csv")
    sub["level_group"] = sub["session_level"].apply(lambda x: x.split("_")[-1])
    
    # groupbyでiter作るときにgroup_levelの順番が崩れないように
    test["session_level"] = test["session_level"].str.replace("13-22", "6")
    sub["session_level"] = sub["session_level"].str.replace("13-22", "6")

    tests = [df[1].drop(columns="session_level").reset_index(drop=True) for df in test.groupby("session_level")]
    subs = [df[1].drop(columns="session_level").reset_index(drop=True) for df in sub.groupby("session_level")]
    return zip(tests, subs)

# %%
def inference(mode):
    if mode == "local_cv":
        # time series apiを模したiterをモックとして用意する
        iter_test = get_mock_iter_test()
        start_time = time.time()
    elif mode == "kaggle_inf":
        env = jo_wilder_310.make_env()
        iter_test = env.iter_test()
        
    model_dict = {}
    features_dict = {}
    for g in level_group_list:
        if mode == "local_cv":
            model_paths = [cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_model_{g}_{i}.lgb" for i in range(cfg.n_splits)]
        elif mode == "kaggle_inf":
            model_paths = [f"/kaggle/input/jo-wilder-{cfg.exp_name}/{cfg.exp_name}_model_{g}_{i}.lgb" for i in range(cfg.n_splits)]
        model_dict[g] = [lgb.Booster(model_file=p) for p in model_paths]
        features_dict[g] = model_dict[g][0].feature_name()
    
    prev_features_df = None
    for (test_sessions, sample_submission) in iter_test:
        level_group = test_sessions["level_group"].values[0]
        test = get_test_dataset(test_sessions, sample_submission)
        features = features_dict[level_group]
        preds = np.zeros(len(test))

        if level_group == "0-4":
            pass
        else:
            test = test.merge(prev_features_df, on=["session_id"], how="left")

        # 前のlevel_groupのquestionパートの経過時間特徴量
        if level_group == "5-12":
            test["0-4_question_duration_time"] = test["5-12_elapsed_time_min"] - test["0-4_elapsed_time_max"]
            test["0-4_question_duration_index"] = test["5-12_index_min"] - test["0-4_index_max"]
        elif level_group == "13-22":
            test["5-12_question_duration_time"] = test["13-22_elapsed_time_min"] - test["5-12_elapsed_time_max"]
            test["5-12_question_duration_index"] = test["13-22_index_min"] - test["5-12_index_max"]

        prev_features_df = test.groupby("session_id").head(1).drop(columns=["question", "correct", "level_group"])

        for i in range(cfg.n_splits):
            model = model_dict[level_group][i]
            preds += model.predict(test[features], num_iteration=model.best_iteration) / cfg.n_splits
        test["pred"] = preds
        preds = (preds>cfg.best_threshold).astype(int)
        sample_submission["correct"] = preds

        # meta_featureの付与
        meta_df = test.groupby("session_id")["pred"].agg(["mean", "max", "min", "std"]).reset_index()
        meta_df = meta_df.rename(columns={"mean":f"{level_group}_pred_mean", "max":f"{level_group}_pred_max", "min":f"{level_group}_pred_min", "std":f"{level_group}_pred_std"})
        prev_features_df = prev_features_df.merge(meta_df, on="session_id", how="left")

        if mode == "local_cv":
            print(sample_submission["correct"].values)
        elif mode == "kaggle_inf":
            env.predict(sample_submission)
    if mode == "local_cv":
        process_time = format(time.time() - start_time, ".1f")
        print("sample_inf処理時間 : ", process_time, "秒")

# %%
if cfg.mode == "local_cv":
    run_train()
inference(cfg.mode)
# Out:
# 0-4
# fold : 0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 49821, number of negative: 6726
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.451484 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 176924
# [LightGBM] [Info] Number of data points in the train set: 56547, number of used features: 1869
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.881055 -> initscore=2.002456
# [LightGBM] [Info] Start training from score 2.002456
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.283852	valid_1's binary_logloss: 0.306125
# [200]	training's binary_logloss: 0.252097	valid_1's binary_logloss: 0.284995
# [300]	training's binary_logloss: 0.233241	valid_1's binary_logloss: 0.276509
# [400]	training's binary_logloss: 0.219154	valid_1's binary_logloss: 0.272327
# [500]	training's binary_logloss: 0.207382	valid_1's binary_logloss: 0.270026
# [600]	training's binary_logloss: 0.197214	valid_1's binary_logloss: 0.26901
# [700]	training's binary_logloss: 0.188311	valid_1's binary_logloss: 0.268494
# [800]	training's binary_logloss: 0.180359	valid_1's binary_logloss: 0.268405
# Early stopping, best iteration is:
# [761]	training's binary_logloss: 0.1833	valid_1's binary_logloss: 0.268349
# fold : 1
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 49692, number of negative: 6855
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 176841
# [LightGBM] [Info] Number of data points in the train set: 56547, number of used features: 1869
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.878773 -> initscore=1.980866
# [LightGBM] [Info] Start training from score 1.980866
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.287013	valid_1's binary_logloss: 0.294087
# [200]	training's binary_logloss: 0.254468	valid_1's binary_logloss: 0.274896
# [300]	training's binary_logloss: 0.235307	valid_1's binary_logloss: 0.267025
# [400]	training's binary_logloss: 0.221011	valid_1's binary_logloss: 0.263147
# [500]	training's binary_logloss: 0.209106	valid_1's binary_logloss: 0.261299
# [600]	training's binary_logloss: 0.198864	valid_1's binary_logloss: 0.260456
# [700]	training's binary_logloss: 0.189854	valid_1's binary_logloss: 0.260001
# [800]	training's binary_logloss: 0.181812	valid_1's binary_logloss: 0.259841
# Early stopping, best iteration is:
# [754]	training's binary_logloss: 0.185372	valid_1's binary_logloss: 0.259808
# fold : 2
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 49772, number of negative: 6778
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.473968 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 176991
# [LightGBM] [Info] Number of data points in the train set: 56550, number of used features: 1869
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.880141 -> initscore=1.993771
# [LightGBM] [Info] Start training from score 1.993771
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.285784	valid_1's binary_logloss: 0.299037
# [200]	training's binary_logloss: 0.2539	valid_1's binary_logloss: 0.277938
# [300]	training's binary_logloss: 0.235061	valid_1's binary_logloss: 0.269347
# [400]	training's binary_logloss: 0.220857	valid_1's binary_logloss: 0.265016
# [500]	training's binary_logloss: 0.209153	valid_1's binary_logloss: 0.262816
# [600]	training's binary_logloss: 0.198982	valid_1's binary_logloss: 0.261797
# [700]	training's binary_logloss: 0.190068	valid_1's binary_logloss: 0.261372
# [800]	training's binary_logloss: 0.182072	valid_1's binary_logloss: 0.261071
# [900]	training's binary_logloss: 0.174691	valid_1's binary_logloss: 0.261115
# Early stopping, best iteration is:
# [822]	training's binary_logloss: 0.180444	valid_1's binary_logloss: 0.261051
# fold : 3
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 49755, number of negative: 6795
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.137471 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 176937
# [LightGBM] [Info] Number of data points in the train set: 56550, number of used features: 1869
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.879841 -> initscore=1.990924
# [LightGBM] [Info] Start training from score 1.990924
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.284798	valid_1's binary_logloss: 0.301499
# [200]	training's binary_logloss: 0.25263	valid_1's binary_logloss: 0.282244
# [300]	training's binary_logloss: 0.233679	valid_1's binary_logloss: 0.274752
# [400]	training's binary_logloss: 0.219461	valid_1's binary_logloss: 0.2711
# [500]	training's binary_logloss: 0.207526	valid_1's binary_logloss: 0.26961
# [600]	training's binary_logloss: 0.197483	valid_1's binary_logloss: 0.268956
# [700]	training's binary_logloss: 0.188468	valid_1's binary_logloss: 0.268677
# [800]	training's binary_logloss: 0.180417	valid_1's binary_logloss: 0.268631
# Early stopping, best iteration is:
# [752]	training's binary_logloss: 0.184136	valid_1's binary_logloss: 0.26859
# fold : 4
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 49804, number of negative: 6746
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.122313 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 176912
# [LightGBM] [Info] Number of data points in the train set: 56550, number of used features: 1869
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.880707 -> initscore=1.999146
# [LightGBM] [Info] Start training from score 1.999146
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.285167	valid_1's binary_logloss: 0.303008
# [200]	training's binary_logloss: 0.253421	valid_1's binary_logloss: 0.280832
# [300]	training's binary_logloss: 0.234622	valid_1's binary_logloss: 0.271708
# [400]	training's binary_logloss: 0.220506	valid_1's binary_logloss: 0.267058
# [500]	training's binary_logloss: 0.208822	valid_1's binary_logloss: 0.264593
# [600]	training's binary_logloss: 0.19864	valid_1's binary_logloss: 0.263374
# [700]	training's binary_logloss: 0.189762	valid_1's binary_logloss: 0.262961
# [800]	training's binary_logloss: 0.181785	valid_1's binary_logloss: 0.262612
# [900]	training's binary_logloss: 0.174514	valid_1's binary_logloss: 0.262521
# Early stopping, best iteration is:
# [836]	training's binary_logloss: 0.17914	valid_1's binary_logloss: 0.262458
# 5-12
# fold : 0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 122655, number of negative: 65835
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.339403 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 461057
# [LightGBM] [Info] Number of data points in the train set: 188490, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650724 -> initscore=0.622224
# [LightGBM] [Info] Start training from score 0.622224
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.576169	valid_1's binary_logloss: 0.581997
# [200]	training's binary_logloss: 0.546579	valid_1's binary_logloss: 0.557174
# [300]	training's binary_logloss: 0.529779	valid_1's binary_logloss: 0.545344
# [400]	training's binary_logloss: 0.519446	valid_1's binary_logloss: 0.54055
# [500]	training's binary_logloss: 0.511514	valid_1's binary_logloss: 0.538217
# [600]	training's binary_logloss: 0.504744	valid_1's binary_logloss: 0.536587
# [700]	training's binary_logloss: 0.498785	valid_1's binary_logloss: 0.53558
# [800]	training's binary_logloss: 0.493441	valid_1's binary_logloss: 0.534881
# [900]	training's binary_logloss: 0.488581	valid_1's binary_logloss: 0.534503
# [1000]	training's binary_logloss: 0.484176	valid_1's binary_logloss: 0.534143
# [1100]	training's binary_logloss: 0.480025	valid_1's binary_logloss: 0.533835
# [1200]	training's binary_logloss: 0.47626	valid_1's binary_logloss: 0.533593
# [1300]	training's binary_logloss: 0.472717	valid_1's binary_logloss: 0.533407
# [1400]	training's binary_logloss: 0.46946	valid_1's binary_logloss: 0.533291
# [1500]	training's binary_logloss: 0.466388	valid_1's binary_logloss: 0.533168
# [1600]	training's binary_logloss: 0.463516	valid_1's binary_logloss: 0.533035
# [1700]	training's binary_logloss: 0.460748	valid_1's binary_logloss: 0.532943
# [1800]	training's binary_logloss: 0.458025	valid_1's binary_logloss: 0.532924
# [1900]	training's binary_logloss: 0.455568	valid_1's binary_logloss: 0.532878
# [2000]	training's binary_logloss: 0.453079	valid_1's binary_logloss: 0.53283
# [2100]	training's binary_logloss: 0.450677	valid_1's binary_logloss: 0.532835
# Early stopping, best iteration is:
# [2026]	training's binary_logloss: 0.452399	valid_1's binary_logloss: 0.532799
# fold : 1
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 122423, number of negative: 66067
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.924549 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 460844
# [LightGBM] [Info] Number of data points in the train set: 188490, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.649493 -> initscore=0.616813
# [LightGBM] [Info] Start training from score 0.616813
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.576407	valid_1's binary_logloss: 0.581041
# [200]	training's binary_logloss: 0.54651	valid_1's binary_logloss: 0.557137
# [300]	training's binary_logloss: 0.529499	valid_1's binary_logloss: 0.546026
# [400]	training's binary_logloss: 0.519185	valid_1's binary_logloss: 0.541586
# [500]	training's binary_logloss: 0.511275	valid_1's binary_logloss: 0.53944
# [600]	training's binary_logloss: 0.504515	valid_1's binary_logloss: 0.538022
# [700]	training's binary_logloss: 0.498577	valid_1's binary_logloss: 0.537124
# [800]	training's binary_logloss: 0.493229	valid_1's binary_logloss: 0.536572
# [900]	training's binary_logloss: 0.488406	valid_1's binary_logloss: 0.536087
# [1000]	training's binary_logloss: 0.483985	valid_1's binary_logloss: 0.53576
# [1100]	training's binary_logloss: 0.479799	valid_1's binary_logloss: 0.5356
# [1200]	training's binary_logloss: 0.476024	valid_1's binary_logloss: 0.535448
# [1300]	training's binary_logloss: 0.472498	valid_1's binary_logloss: 0.535283
# [1400]	training's binary_logloss: 0.469189	valid_1's binary_logloss: 0.535184
# [1500]	training's binary_logloss: 0.466057	valid_1's binary_logloss: 0.535121
# [1600]	training's binary_logloss: 0.463187	valid_1's binary_logloss: 0.535093
# [1700]	training's binary_logloss: 0.460411	valid_1's binary_logloss: 0.534994
# [1800]	training's binary_logloss: 0.45774	valid_1's binary_logloss: 0.534981
# [1900]	training's binary_logloss: 0.455271	valid_1's binary_logloss: 0.53494
# [2000]	training's binary_logloss: 0.452738	valid_1's binary_logloss: 0.534936
# Early stopping, best iteration is:
# [1937]	training's binary_logloss: 0.454329	valid_1's binary_logloss: 0.534914
# fold : 2
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 122249, number of negative: 66251
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 3.045367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 461035
# [LightGBM] [Info] Number of data points in the train set: 188500, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.648536 -> initscore=0.612609
# [LightGBM] [Info] Start training from score 0.612609
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.576806	valid_1's binary_logloss: 0.578902
# [200]	training's binary_logloss: 0.546971	valid_1's binary_logloss: 0.555219
# [300]	training's binary_logloss: 0.530036	valid_1's binary_logloss: 0.544157
# [400]	training's binary_logloss: 0.519722	valid_1's binary_logloss: 0.539861
# [500]	training's binary_logloss: 0.511813	valid_1's binary_logloss: 0.537739
# [600]	training's binary_logloss: 0.505041	valid_1's binary_logloss: 0.536359
# [700]	training's binary_logloss: 0.499149	valid_1's binary_logloss: 0.53554
# [800]	training's binary_logloss: 0.493863	valid_1's binary_logloss: 0.534991
# [900]	training's binary_logloss: 0.489061	valid_1's binary_logloss: 0.534498
# [1000]	training's binary_logloss: 0.484632	valid_1's binary_logloss: 0.534191
# [1100]	training's binary_logloss: 0.480487	valid_1's binary_logloss: 0.533915
# [1200]	training's binary_logloss: 0.476767	valid_1's binary_logloss: 0.533806
# [1300]	training's binary_logloss: 0.473282	valid_1's binary_logloss: 0.533633
# [1400]	training's binary_logloss: 0.470038	valid_1's binary_logloss: 0.533495
# [1500]	training's binary_logloss: 0.466936	valid_1's binary_logloss: 0.533338
# [1600]	training's binary_logloss: 0.464034	valid_1's binary_logloss: 0.533301
# [1700]	training's binary_logloss: 0.461301	valid_1's binary_logloss: 0.533237
# [1800]	training's binary_logloss: 0.458565	valid_1's binary_logloss: 0.533213
# [1900]	training's binary_logloss: 0.456103	valid_1's binary_logloss: 0.533108
# [2000]	training's binary_logloss: 0.453615	valid_1's binary_logloss: 0.533077
# [2100]	training's binary_logloss: 0.451245	valid_1's binary_logloss: 0.533059
# [2200]	training's binary_logloss: 0.44909	valid_1's binary_logloss: 0.533108
# Early stopping, best iteration is:
# [2107]	training's binary_logloss: 0.451084	valid_1's binary_logloss: 0.533052
# fold : 3
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 122566, number of negative: 65934
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.589763 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 461135
# [LightGBM] [Info] Number of data points in the train set: 188500, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650218 -> initscore=0.619995
# [LightGBM] [Info] Start training from score 0.619995
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.576397	valid_1's binary_logloss: 0.581945
# [200]	training's binary_logloss: 0.546874	valid_1's binary_logloss: 0.557284
# [300]	training's binary_logloss: 0.530091	valid_1's binary_logloss: 0.545382
# [400]	training's binary_logloss: 0.519842	valid_1's binary_logloss: 0.540603
# [500]	training's binary_logloss: 0.511945	valid_1's binary_logloss: 0.538081
# [600]	training's binary_logloss: 0.505184	valid_1's binary_logloss: 0.536392
# [700]	training's binary_logloss: 0.499293	valid_1's binary_logloss: 0.53532
# [800]	training's binary_logloss: 0.493962	valid_1's binary_logloss: 0.534556
# [900]	training's binary_logloss: 0.489107	valid_1's binary_logloss: 0.534079
# [1000]	training's binary_logloss: 0.484666	valid_1's binary_logloss: 0.533638
# [1100]	training's binary_logloss: 0.480528	valid_1's binary_logloss: 0.533286
# [1200]	training's binary_logloss: 0.476789	valid_1's binary_logloss: 0.533068
# [1300]	training's binary_logloss: 0.473279	valid_1's binary_logloss: 0.53293
# [1400]	training's binary_logloss: 0.47001	valid_1's binary_logloss: 0.532786
# [1500]	training's binary_logloss: 0.466892	valid_1's binary_logloss: 0.532771
# [1600]	training's binary_logloss: 0.464005	valid_1's binary_logloss: 0.53266
# [1700]	training's binary_logloss: 0.461263	valid_1's binary_logloss: 0.532621
# [1800]	training's binary_logloss: 0.458682	valid_1's binary_logloss: 0.532549
# [1900]	training's binary_logloss: 0.456229	valid_1's binary_logloss: 0.532469
# [2000]	training's binary_logloss: 0.45367	valid_1's binary_logloss: 0.532447
# [2100]	training's binary_logloss: 0.451322	valid_1's binary_logloss: 0.532461
# Early stopping, best iteration is:
# [2059]	training's binary_logloss: 0.452263	valid_1's binary_logloss: 0.53242
# fold : 4
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 122635, number of negative: 65865
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.302637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 459930
# [LightGBM] [Info] Number of data points in the train set: 188500, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650584 -> initscore=0.621605
# [LightGBM] [Info] Start training from score 0.621605
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.576025	valid_1's binary_logloss: 0.582386
# [200]	training's binary_logloss: 0.546458	valid_1's binary_logloss: 0.557702
# [300]	training's binary_logloss: 0.529606	valid_1's binary_logloss: 0.54583
# [400]	training's binary_logloss: 0.519301	valid_1's binary_logloss: 0.540974
# [500]	training's binary_logloss: 0.511387	valid_1's binary_logloss: 0.538507
# [600]	training's binary_logloss: 0.504564	valid_1's binary_logloss: 0.536884
# [700]	training's binary_logloss: 0.498608	valid_1's binary_logloss: 0.535818
# [800]	training's binary_logloss: 0.493276	valid_1's binary_logloss: 0.535164
# [900]	training's binary_logloss: 0.488377	valid_1's binary_logloss: 0.534645
# [1000]	training's binary_logloss: 0.483962	valid_1's binary_logloss: 0.534301
# [1100]	training's binary_logloss: 0.479814	valid_1's binary_logloss: 0.534092
# [1200]	training's binary_logloss: 0.476061	valid_1's binary_logloss: 0.533946
# [1300]	training's binary_logloss: 0.472554	valid_1's binary_logloss: 0.533832
# [1400]	training's binary_logloss: 0.469286	valid_1's binary_logloss: 0.53371
# [1500]	training's binary_logloss: 0.466146	valid_1's binary_logloss: 0.533623
# [1600]	training's binary_logloss: 0.463243	valid_1's binary_logloss: 0.533548
# [1700]	training's binary_logloss: 0.460394	valid_1's binary_logloss: 0.533515
# [1800]	training's binary_logloss: 0.457748	valid_1's binary_logloss: 0.533491
# [1900]	training's binary_logloss: 0.455274	valid_1's binary_logloss: 0.533456
# [2000]	training's binary_logloss: 0.452827	valid_1's binary_logloss: 0.533399
# [2100]	training's binary_logloss: 0.450401	valid_1's binary_logloss: 0.533382
# [2200]	training's binary_logloss: 0.448267	valid_1's binary_logloss: 0.533355
# [2300]	training's binary_logloss: 0.445997	valid_1's binary_logloss: 0.533362
# [2400]	training's binary_logloss: 0.44384	valid_1's binary_logloss: 0.533345
# [2500]	training's binary_logloss: 0.441861	valid_1's binary_logloss: 0.533368
# Early stopping, best iteration is:
# [2416]	training's binary_logloss: 0.44355	valid_1's binary_logloss: 0.533334
# 13-22
# fold : 0
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 67313, number of negative: 26932
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.501523 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 491381
# [LightGBM] [Info] Number of data points in the train set: 94245, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.714234 -> initscore=0.916038
# [LightGBM] [Info] Start training from score 0.916038
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.539999	valid_1's binary_logloss: 0.549912
# [200]	training's binary_logloss: 0.511815	valid_1's binary_logloss: 0.527077
# [300]	training's binary_logloss: 0.493581	valid_1's binary_logloss: 0.515745
# [400]	training's binary_logloss: 0.4813	valid_1's binary_logloss: 0.511349
# [500]	training's binary_logloss: 0.471421	valid_1's binary_logloss: 0.509291
# [600]	training's binary_logloss: 0.462325	valid_1's binary_logloss: 0.507908
# [700]	training's binary_logloss: 0.454293	valid_1's binary_logloss: 0.507052
# [800]	training's binary_logloss: 0.446981	valid_1's binary_logloss: 0.506483
# [900]	training's binary_logloss: 0.440463	valid_1's binary_logloss: 0.506108
# [1000]	training's binary_logloss: 0.434531	valid_1's binary_logloss: 0.505982
# [1100]	training's binary_logloss: 0.429023	valid_1's binary_logloss: 0.505738
# [1200]	training's binary_logloss: 0.424042	valid_1's binary_logloss: 0.505606
# [1300]	training's binary_logloss: 0.419355	valid_1's binary_logloss: 0.50544
# [1400]	training's binary_logloss: 0.415009	valid_1's binary_logloss: 0.505454
# [1500]	training's binary_logloss: 0.410849	valid_1's binary_logloss: 0.505396
# [1600]	training's binary_logloss: 0.407148	valid_1's binary_logloss: 0.505345
# Early stopping, best iteration is:
# [1549]	training's binary_logloss: 0.408918	valid_1's binary_logloss: 0.50531
# fold : 1
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 66951, number of negative: 27294
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.509098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 491452
# [LightGBM] [Info] Number of data points in the train set: 94245, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.710393 -> initscore=0.897294
# [LightGBM] [Info] Start training from score 0.897294
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.543278	valid_1's binary_logloss: 0.537927
# [200]	training's binary_logloss: 0.514989	valid_1's binary_logloss: 0.516141
# [300]	training's binary_logloss: 0.496802	valid_1's binary_logloss: 0.505351
# [400]	training's binary_logloss: 0.484559	valid_1's binary_logloss: 0.501208
# [500]	training's binary_logloss: 0.474462	valid_1's binary_logloss: 0.498999
# [600]	training's binary_logloss: 0.465555	valid_1's binary_logloss: 0.497627
# [700]	training's binary_logloss: 0.457391	valid_1's binary_logloss: 0.496827
# [800]	training's binary_logloss: 0.45013	valid_1's binary_logloss: 0.496344
# [900]	training's binary_logloss: 0.443697	valid_1's binary_logloss: 0.495978
# [1000]	training's binary_logloss: 0.437892	valid_1's binary_logloss: 0.495864
# [1100]	training's binary_logloss: 0.4323	valid_1's binary_logloss: 0.495584
# [1200]	training's binary_logloss: 0.427329	valid_1's binary_logloss: 0.495517
# [1300]	training's binary_logloss: 0.422505	valid_1's binary_logloss: 0.495353
# [1400]	training's binary_logloss: 0.418167	valid_1's binary_logloss: 0.495347
# [1500]	training's binary_logloss: 0.413804	valid_1's binary_logloss: 0.495301
# [1600]	training's binary_logloss: 0.409913	valid_1's binary_logloss: 0.495274
# [1700]	training's binary_logloss: 0.406384	valid_1's binary_logloss: 0.495241
# [1800]	training's binary_logloss: 0.402608	valid_1's binary_logloss: 0.495173
# [1900]	training's binary_logloss: 0.399402	valid_1's binary_logloss: 0.495238
# Early stopping, best iteration is:
# [1836]	training's binary_logloss: 0.401333	valid_1's binary_logloss: 0.495143
# fold : 2
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 66989, number of negative: 27261
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.438761 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 491395
# [LightGBM] [Info] Number of data points in the train set: 94250, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.710759 -> initscore=0.899071
# [LightGBM] [Info] Start training from score 0.899071
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.542874	valid_1's binary_logloss: 0.539828
# [200]	training's binary_logloss: 0.514594	valid_1's binary_logloss: 0.518255
# [300]	training's binary_logloss: 0.496341	valid_1's binary_logloss: 0.507429
# [400]	training's binary_logloss: 0.484132	valid_1's binary_logloss: 0.503363
# [500]	training's binary_logloss: 0.474108	valid_1's binary_logloss: 0.501559
# [600]	training's binary_logloss: 0.464927	valid_1's binary_logloss: 0.500035
# [700]	training's binary_logloss: 0.456847	valid_1's binary_logloss: 0.499208
# [800]	training's binary_logloss: 0.449518	valid_1's binary_logloss: 0.498704
# [900]	training's binary_logloss: 0.443008	valid_1's binary_logloss: 0.498379
# [1000]	training's binary_logloss: 0.437056	valid_1's binary_logloss: 0.498054
# [1100]	training's binary_logloss: 0.431366	valid_1's binary_logloss: 0.497884
# [1200]	training's binary_logloss: 0.426485	valid_1's binary_logloss: 0.497757
# [1300]	training's binary_logloss: 0.421818	valid_1's binary_logloss: 0.497664
# [1400]	training's binary_logloss: 0.417595	valid_1's binary_logloss: 0.497549
# [1500]	training's binary_logloss: 0.413339	valid_1's binary_logloss: 0.497446
# [1600]	training's binary_logloss: 0.409391	valid_1's binary_logloss: 0.49727
# [1700]	training's binary_logloss: 0.405609	valid_1's binary_logloss: 0.497204
# [1800]	training's binary_logloss: 0.402175	valid_1's binary_logloss: 0.497127
# [1900]	training's binary_logloss: 0.398916	valid_1's binary_logloss: 0.49714
# [2000]	training's binary_logloss: 0.395684	valid_1's binary_logloss: 0.497115
# [2100]	training's binary_logloss: 0.392732	valid_1's binary_logloss: 0.497127
# Early stopping, best iteration is:
# [2061]	training's binary_logloss: 0.393883	valid_1's binary_logloss: 0.497084
# fold : 3
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 67214, number of negative: 27036
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.668686 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 491454
# [LightGBM] [Info] Number of data points in the train set: 94250, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.713146 -> initscore=0.910712
# [LightGBM] [Info] Start training from score 0.910712
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.540547	valid_1's binary_logloss: 0.547908
# [200]	training's binary_logloss: 0.512125	valid_1's binary_logloss: 0.525924
# [300]	training's binary_logloss: 0.493796	valid_1's binary_logloss: 0.514893
# [400]	training's binary_logloss: 0.481513	valid_1's binary_logloss: 0.510762
# [500]	training's binary_logloss: 0.471478	valid_1's binary_logloss: 0.508995
# [600]	training's binary_logloss: 0.462461	valid_1's binary_logloss: 0.507663
# [700]	training's binary_logloss: 0.454365	valid_1's binary_logloss: 0.506935
# [800]	training's binary_logloss: 0.44711	valid_1's binary_logloss: 0.506476
# [900]	training's binary_logloss: 0.440796	valid_1's binary_logloss: 0.506338
# [1000]	training's binary_logloss: 0.434797	valid_1's binary_logloss: 0.506148
# [1100]	training's binary_logloss: 0.429273	valid_1's binary_logloss: 0.506098
# [1200]	training's binary_logloss: 0.424223	valid_1's binary_logloss: 0.505936
# [1300]	training's binary_logloss: 0.419604	valid_1's binary_logloss: 0.50599
# Early stopping, best iteration is:
# [1222]	training's binary_logloss: 0.423184	valid_1's binary_logloss: 0.50588
# fold : 4
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 67245, number of negative: 27005
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.821261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 489398
# [LightGBM] [Info] Number of data points in the train set: 94250, number of used features: 2000
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.713475 -> initscore=0.912321
# [LightGBM] [Info] Start training from score 0.912321
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.540357	valid_1's binary_logloss: 0.5481
# [200]	training's binary_logloss: 0.511971	valid_1's binary_logloss: 0.52598
# [300]	training's binary_logloss: 0.49366	valid_1's binary_logloss: 0.514764
# [400]	training's binary_logloss: 0.48132	valid_1's binary_logloss: 0.510303
# [500]	training's binary_logloss: 0.471386	valid_1's binary_logloss: 0.508232
# [600]	training's binary_logloss: 0.462255	valid_1's binary_logloss: 0.506641
# [700]	training's binary_logloss: 0.45425	valid_1's binary_logloss: 0.505709
# [800]	training's binary_logloss: 0.446928	valid_1's binary_logloss: 0.505235
# [900]	training's binary_logloss: 0.440493	valid_1's binary_logloss: 0.505059
# [1000]	training's binary_logloss: 0.43477	valid_1's binary_logloss: 0.504982
# [1100]	training's binary_logloss: 0.429041	valid_1's binary_logloss: 0.504719
# [1200]	training's binary_logloss: 0.424141	valid_1's binary_logloss: 0.504602
# Early stopping, best iteration is:
# [1197]	training's binary_logloss: 0.424264	valid_1's binary_logloss: 0.504587
# logloss 0.480203
# best_score 0.699341
# best_threshold 0.630
# ------------------------------
# Q1 : F1 = 0.640293
# Q2 : F1 = 0.546642
# Q3 : F1 = 0.593599
# Q4 : F1 = 0.641581
# Q5 : F1 = 0.405533
# Q6 : F1 = 0.615395
# Q7 : F1 = 0.585261
# Q8 : F1 = 0.347186
# Q9 : F1 = 0.570853
# Q10 : F1 = 0.382175
# Q11 : F1 = 0.410577
# Q12 : F1 = 0.602308
# Q13 : F1 = 0.422934
# Q14 : F1 = 0.505145
# Q15 : F1 = 0.377196
# Q16 : F1 = 0.428449
# Q17 : F1 = 0.381714
# Q18 : F1 = 0.567953
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 if cfg.mode == "local_cv":
#       2     run_train()
# ----> 3 inference(cfg.mode)
#
# Cell In[14], line 23, in inference(mode)
#      21 for (test_sessions, sample_submission) in iter_test:
#      22     level_group = test_sessions["level_group"].values[0]
# ---> 23     test = get_test_dataset(test_sessions, sample_submission)
#      24     features = features_dict[level_group]
#      25     preds = np.zeros(len(test))
#
# Cell In[10], line 18, in get_test_dataset(sessions, labels)
#      16 # 特徴量生成
#      17 feat = FeaturesInf(sessions, labels)
# ---> 18 test = feat.get_test()
#      19 test["question"] = test["question"].astype("category")
#      21 return test
#
# Cell In[9], line 114, in FeaturesInf.get_test(self)
#     112 def get_test(self):
#     113     self._prep()
# --> 114     self._total_record_cnt()
#     115     self._group_elapsed_time()
#     116     self._cat_record_cnt("event_name")
#
# Cell In[9], line 23, in FeaturesInf._total_record_cnt(self)
#      20 """level_groupごとのレコード数
#      21 """
#      22 feat_name = f"{self.group}_record_cnt"
# ---> 23 if cfg.feature_select & feat_name not in need_create_features:
#      24     pass
#      25 else:
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'str'
