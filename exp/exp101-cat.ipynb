# %% [markdown]
# # exp101

# %% [markdown]
# shift + , shift - 両方

# %%
import os
import sys
import traceback
import gc
import re
import time
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from collections import defaultdict

import pandas as pd
import numpy as np
import polars as pl
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.model_selection import GroupKFold
import lightgbm as lgb
from xgboost import XGBClassifier
from catboost import CatBoost, Pool

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import itertools

import Levenshtein

import warnings
warnings.simplefilter('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
@dataclass
class Cfg:
    mode = "local_cv" # "local_cv" or "kaggle_inf" 
    exp_name = "exp101-cat"
    input_dir = "/mnt/predict-student-performance-from-game-play/input/"
    output_dir = "/mnt/predict-student-performance-from-game-play/output/"
    prep_dir = "/mnt/predict-student-performance-from-game-play/prep/"
    seed = 42
    n_splits = 5
    best_threshold = 0.630 # local_cvの結果を入れる
    base_exp = None # 特徴量重要度を使う元のexp
    n_features = 500 # 特徴量削減の数
cfg = Cfg()

if cfg.mode == "local_cv":
    os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name), exist_ok=True)
    os.makedirs(os.path.join(cfg.output_dir, cfg.exp_name, "cache"), exist_ok=True)
    import cudf

elif cfg.mode == "kaggle_inf":
    import jo_wilder_310

# %%
params = {
    'loss_function': 'Logloss',
    'eval_metric': 'Logloss',
    'learning_rate': 0.03,
    'num_boost_round': 9999,
    'random_seed': cfg.seed,
    "od_type": "Iter"
}

# %%
level_group_list = ['0-4', '5-12', '13-22']
level_group_map = {
    "q1":"0-4", "q2":"0-4", "q3":"0-4",
    "q4":"5-12", "q5":"5-12", "q6":"5-12", "q7":"5-12", "q8":"5-12", "q9":"5-12", "q10":"5-12", "q11":"5-12", "q12":"5-12", "q13":"5-12",
    "q14":"13-22", "q15":"13-22", "q16":"13-22", "q17":"13-22", "q18":"13-22"  
}

# %%
ideal_seqs = {}
ideal_seqs["0-4"] = "a b c d c f g"
ideal_seqs["5-12"] = "g c b h b c e i e c j k l m l c e i e c n"
ideal_seqs["13-22"] = "n c b o b c e i e c b o b c p c q r l m l c e i e c s"

# %%
n_features = {}
n_features["0-4"] = 600
n_features["5-12"] = 1000
n_features["13-22"] = 1000

# %%
if cfg.mode == "local_cv":
    with open(cfg.prep_dir + 'cat_col_lists_v3.pkl', 'rb') as f:
        cat_col_lists = pickle.load(f) 
    with open(cfg.prep_dir + 'room_fqid_encoder.pkl', 'rb') as f:
        room_fqid_encoder = pickle.load(f) 

elif cfg.mode == "kaggle_inf":
    with open("/kaggle/input/psp-cat-col-lists/cat_col_lists_v3.pkl", 'rb') as f:
        cat_col_lists = pickle.load(f) 
    with open("/kaggle/input/room-fqid-encoder/room_fqid_encoder.pkl", 'rb') as f:
        room_fqid_encoder = pickle.load(f)

# %%
def transform_labels_df_train(labels_):
    """
    labelsデータを整形する
    """
    labels = labels_.copy()
    labels["question"] = labels["session_id"].apply(lambda x: x.split("_")[1].replace("q", "")).astype(int)
    labels["session_id"] = labels["session_id"].apply(lambda x: x.split("_")[0]).astype(int)

    # trainの特徴量と結合するためにquestionに対応するlabel_groupを列として設けておく
    labels["level_group"] = ""
    labels.loc[labels["question"]<=3, "level_group"] = "0-4"
    labels.loc[(labels["question"]>=4)&(labels["question"]<=13), "level_group"] = "5-12"
    labels.loc[labels["question"]>=14, "level_group"] = "13-22"

    return labels


def transform_labels_df_inf(labels_):
    """
    labelsデータを整形する
    """
    labels = labels_.copy()
    labels["question"] = labels["session_id"].apply(lambda x: x.split("_")[1].replace("q", "")).astype(int)
    labels["session_id"] = labels["session_id"].apply(lambda x: x.split("_")[0]).astype(int)

    return labels

# %%
def diff_maxmin(s):
    try:
        return s.max() - s.min()
    except:
        return -1

# %%
class Features:
    def __init__(self, sessions_df, need_create_features=None):
        self.sessions_df = pl.from_pandas(sessions_df).sort(["session_id", "index"])
        self.group = sessions_df["level_group"].values[0]
        self.need_create_features = need_create_features

    def prep(self):
        self.sessions_df = self.sessions_df.with_columns(
            [(pl.col("elapsed_time") - pl.col("elapsed_time").shift(1)).clip(0, 1e9).fill_null(0).over(["session_id"]).alias("time_diff"),
             (pl.col("elapsed_time").shift(-1)-pl.col("elapsed_time")).clip(0, 1e9).fill_null(0).over(["session_id"]).alias("time_diff2"),
             (pl.col("event_name") + "_" + pl.col("name")).alias("event_name+name"),
             (pl.col("event_name") + "_" + pl.col("room_fqid")).alias("event_name+room_fqid"),
             (pl.col("event_name") + "_" + pl.col("fqid")).alias("event_name+fqid"),
             (pl.col("level").cast(pl.Utf8) + "_" + pl.col("room_fqid")).alias("level+room_fqid"),
             (pl.col("room_fqid").map_dict(room_fqid_encoder).alias("room_fqid_encode"))
             ]
        )

    def get_aggs(self):
        g = self.group
        cats = cat_col_lists[g]
        aggs = []

        # トータルレコード数
        aggs += [pl.col("index").count().alias(f"{g}_record_cnt")]

        # グループ全体の経過時間
        aggs += [pl.col("elapsed_time").apply(lambda s:s.max() - s.min()).alias(f"{g}_elapsed_time")]

        # 各categoryごとのレコード数
        for c in ["event_name", "name", "page", "level", "room_fqid", "fqid", "event_name+name", "event_name+room_fqid", "event_name+fqid", "level+room_fqid"]:
            aggs += [pl.col("index").filter(pl.col(c)==v).count().fill_null(0).alias(f"{g}_{c}_{str(v)}_record_cnt") for v in cats[c]]
        
        # 各categoryごとのユニーク数
        for c in ["event_name", "name", "page", "level", "room_fqid", "fqid", "event_name+name", "event_name+room_fqid", "event_name+fqid", "level+room_fqid"]:
            aggs += [pl.col(c).drop_nulls().n_unique().fill_null(0).alias(f"{g}_{c}_nunique")]

        # 各level - categoryごとのユニーク数
        for c in ["event_name", "name", "page", "level", "room_fqid", "fqid", "event_name+name", "event_name+room_fqid", "event_name+fqid", "level+room_fqid"]:
            aggs += [pl.col(c).filter(pl.col("level")==l).drop_nulls().n_unique().fill_null(0).alias(f"{g}_leve{l}_{c}_nunique") for l in cats["level"]]

        # 集計量
        for v in ["elapsed_time", "index"]:
            aggs += [pl.col(v).max().fill_null(-1).alias(f"{g}_{v}_max").cast(pl.Float32), 
                     pl.col(v).max().fill_null(-1).alias(f"{g}_{v}_min").cast(pl.Float32)]

        for v in ["time_diff", "time_diff2", "hover_duration"]:
            aggs += [pl.col(v).max().fill_null(-1).alias(f"{g}_{v}_max").cast(pl.Float32), 
                     pl.col(v).min().fill_null(-1).alias(f"{g}_{v}_min").cast(pl.Float32), 
                     pl.col(v).std().fill_null(-1).alias(f"{g}_{v}_std").cast(pl.Float32),
                     pl.col(v).mean().fill_null(-1).alias(f"{g}_{v}_mean").cast(pl.Float32), 
                     pl.col(v).sum().fill_null(-1).alias(f"{g}_{v}_sum").cast(pl.Float32), 
                     pl.col(v).median().fill_null(-1).alias(f"{g}_{v}_median").cast(pl.Float32)]
            
            aggs += [pl.col(v).quantile(0.25, "nearest").fill_null(-1).alias(f"{g}_{v}_quantile025"),
                     pl.col(v).quantile(0.75, "nearest").fill_null(-1).alias(f"{g}_{v}_quantile075")
            ]
            
        # カテゴリ×集計量
        cs = ["event_name", "room_fqid", "fqid", "text_fqid", "level", "name", "event_name+name", "event_name+room_fqid", "level+room_fqid"]
        vs = ["time_diff", "time_diff2"]
        for c, v in itertools.product(cs, vs):
            aggs += [pl.col(v).filter(pl.col(c)==cat).max().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_max").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).min().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_min").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).std().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_std").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).mean().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_mean").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).median().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_median").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).sum().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_sum").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).quantile(0.25, "nearest").fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_quantile025").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).quantile(0.75, "nearest").fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_quantile075").cast(pl.Float32) for cat in cats[c]]

        cs = ["event_name", "room_fqid", "fqid", "text_fqid", "level", "name", "event_name+name", "event_name+room_fqid", "level+room_fqid"]
        vs = ["elapsed_time", "index"]
        for c, v in itertools.product(cs, vs):
            aggs += [pl.col(v).filter(pl.col(c)==cat).max().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_max").cast(pl.Float32) for cat in cats[c]]
            aggs += [pl.col(v).filter(pl.col(c)==cat).min().fill_null(-1).alias(f"{g}_{c}_{cat}_{v}_min").cast(pl.Float32) for cat in cats[c]]

        # カテゴリの変化回数
        for c in ["room_fqid", "text_fqid"]:
            aggs += [(pl.col(c) != pl.col(c).shift(1)).sum().alias(f"{g}_{c}_change_cnt")]

        # levelごとのカテゴリ変化回数
        for c in ["room_fqid", "text_fqid"]:
            aggs += [pl.col(c).filter((pl.col("level")==l)&(pl.col(c) != pl.col(c).shift(1))).count().alias(f"{g}_level{l}_{c}_change_cnt") for l in cats["level"]]

        # object_hoverのduration関連の特徴量（各fqidごと）
        fqids = [c.removeprefix("object_hover_") for c in cats["event_name+fqid"] if "object_hover" in c]
        for fqid in fqids:
            aggs += [pl.col("hover_duration").filter((pl.col("event_name")=="object_hover") & (pl.col("fqid")==fqid)).max().fill_null(-1).cast(pl.Float32).alias(f"{g}_object_hover_{fqid}_hover_duration_max"),
                     pl.col("hover_duration").filter((pl.col("event_name")=="object_hover") & (pl.col("fqid")==fqid)).min().fill_null(-1).cast(pl.Float32).alias(f"{g}_object_hover_{fqid}_hover_duration_min"),
                     pl.col("hover_duration").filter((pl.col("event_name")=="object_hover") & (pl.col("fqid")==fqid)).std().fill_null(-1).cast(pl.Float32).alias(f"{g}_object_hover_{fqid}_hover_duration_std"),
                     pl.col("hover_duration").filter((pl.col("event_name")=="object_hover") & (pl.col("fqid")==fqid)).mean().fill_null(-1).cast(pl.Float32).alias(f"{g}_object_hover_{fqid}_hover_duration_mean"),
                     pl.col("hover_duration").filter((pl.col("event_name")=="object_hover") & (pl.col("fqid")==fqid)).median().fill_null(-1).cast(pl.Float32).alias(f"{g}_object_hover_{fqid}_hover_duration_median"),
                     pl.col("hover_duration").filter((pl.col("event_name")=="object_hover") & (pl.col("fqid")==fqid)).sum().fill_null(-1).cast(pl.Float32).alias(f"{g}_object_hover_{fqid}_hover_duration_sum")
                    ]

        # miniゲームの所要時間
        if g == "0-4":
            for fqid_start, fqid_end in zip(["tunic", "plaque"],["tunic.hub.slip", "plaque.face.date"]):
                aggs += [
                    pl.col("index").filter(((pl.col("event_name")=="navigate_click")&(pl.col("fqid")==fqid_start))|((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid_end))).apply(diff_maxmin).alias(f"{g}_minigame_{fqid_start}_index_cnt"),
                    pl.col("elapsed_time").filter(((pl.col("event_name")=="navigate_click")&(pl.col("fqid")==fqid_start))|((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid_end))).apply(diff_maxmin).alias(f"{g}_minigame_{fqid_start}_duration")
                ]
        elif g == "5-12":
            for fqid_start, fqid_end in zip(["businesscards", "logbook", "reader", "journals"],["businesscards.card_bingo.bingo", "logbook.page.bingo", "reader.paper2.bingo", "journals.pic_2.bingo"]):
                aggs += [
                    pl.col("index").filter(((pl.col("event_name")=="navigate_click")&(pl.col("fqid")==fqid_start))|((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid_end))).apply(diff_maxmin).alias(f"{g}_minigame_{fqid_start}_index_cnt"),
                    pl.col("elapsed_time").filter(((pl.col("event_name")=="navigate_click")&(pl.col("fqid")==fqid_start))|((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid_end))).apply(diff_maxmin).alias(f"{g}_minigame_{fqid_start}_duration")
                ]
        elif g == "13-22":
            for fqid_start, fqid_end in zip(["tracks", "reader_flag", "journals_flag", "directory"],["tracks.hub.deer", "reader_flag.paper2.bingo", "journals_flag.pic_0.bingo", "directory.closeup.archivist"]):
                aggs += [
                    pl.col("index").filter(((pl.col("event_name")=="navigate_click")&(pl.col("fqid")==fqid_start))|((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid_end))).apply(diff_maxmin).alias(f"{g}_minigame_{fqid_start}_index_cnt"),
                    pl.col("elapsed_time").filter(((pl.col("event_name")=="navigate_click")&(pl.col("fqid")==fqid_start))|((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid_end))).apply(diff_maxmin).alias(f"{g}_minigame_{fqid_start}_duration")
                ]

        # miniゲーム中のクリック座標
        if g == "0-4":
            fqids = ["tunic", "plaque"]
        elif g == "5-12":
            fqids = ["businesscards", "logbook", "reader", "journals"]
        elif g == "13-22":
            fqids = ["tracks", "reader_flag", "journals_flag", "directory"]

        for fqid in fqids:
            aggs += [
                pl.col("room_coor_x").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).first().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_first_click_room_coor_x"),
                pl.col("room_coor_y").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).first().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_first_click_room_coor_y"),
                pl.col("room_coor_x").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).last().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_last_click_room_coor_x"),
                pl.col("room_coor_y").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).last().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_last_click_room_coor_y"),
                pl.col("room_coor_x").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).mean().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_click_room_coor_x_mean"),
                pl.col("room_coor_y").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).mean().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_click_room_coor_y_mean"),
                pl.col("room_coor_x").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).std().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_click_room_coor_x_std"),
                pl.col("room_coor_y").filter((pl.col("event_name")=="object_click")&(pl.col("fqid")==fqid)).std().fill_null(-1).cast(pl.Float32).alias(f"{g}_{fqid}_click_room_coor_y_std"),
            ]
        
        # 理想系列からのLevenshtein距離
        aggs += [pl.col("room_fqid_encode").filter(pl.col("room_fqid_encode")!=pl.col("room_fqid_encode").shift(1)).str.concat(" ").apply(lambda x: Levenshtein.distance(x, ideal_seqs[g])).alias(f"{g}_room_fqid_leven_dist")]

        # 生成する特徴量を限定
        if self.need_create_features is not None:
            feats = [re.findall(r'alias\("(.*)"\)', str(a))[0] for a in aggs]
            aggs = [aggs[i] for i, f in enumerate(feats) if f in self.need_create_features]

        return aggs

    def get_features(self):
        self.prep()
        aggs = self.get_aggs()
        features = self.sessions_df.groupby(["session_id"], maintain_order=True).agg(aggs)
        return features.to_pandas()

# %%
def get_train_dataset(sessions, labels):
    # labelデータの整形
    labels = transform_labels_df_train(labels)

    # 特徴量生成
    features = Features(sessions).get_features()
    train = labels.merge(features, on=["session_id"], how="left")
    train["question"] = train["question"].astype("category")

    return train

def get_test_dataset(sessions, labels, need_create_features=None):
    # labelデータの整形
    labels = transform_labels_df_inf(labels)

    # 特徴量生成
    features = Features(sessions, need_create_features).get_features()
    test = labels.merge(features, on=["session_id"], how="left")
    test["question"] = test["question"].astype("category")

    return test

# %%
def calc_metrics(oof):
    logloss = log_loss(oof["correct"], oof["pred"])

    # find best th
    scores = []; thresholds = []
    best_score = 0; best_threshold = 0

    for threshold in np.arange(0.4,0.81,0.01):
        preds = (oof["pred"].values>threshold).astype(int)
        m = f1_score(oof["correct"].values, preds, average='macro')   
        scores.append(m)
        thresholds.append(threshold)
        if m>best_score:
            best_score = m
            best_threshold = threshold
    print("logloss", format(logloss, ".6f"))
    print("best_score", format(best_score, ".6f"))
    print("best_threshold", format(best_threshold, ".3f"))

    # Q別スコア
    print("---"*10)
    for q in range(18):
        q = q + 1
        preds = (oof[oof["question"]==q]["pred"].values>threshold).astype(int)
        m = f1_score(oof[oof["question"]==q]["correct"].values, preds, average='macro')
        print(f"Q{q} : F1 = {format(m, '.6f')}")
    return best_threshold

# %%
class FeaturesSelect:
    def __init__(self, df, init_features, corr_th=0.99):
        self.init_features = init_features
        self.df = cudf.from_pandas(df)
        self.corr_th = corr_th
        self.drop_cols = []
    
    def _high_corr_features_drop(self):
        num_cols = self.df[self.init_features].select_dtypes(include="number").columns

        # 特徴量間の相関行列を計算
        corr_matrix = self.df[num_cols].fillna(-1).corr().abs().to_pandas()
        # 相関行列の上三角行列を取得します。（相関行列が対称であるため、重複する相関を取り除くため）
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

        drop_cols = []
        for c in num_cols:
            if any(upper[c] > self.corr_th):
                drop_cols.append(c)
                upper = upper.drop(index=c)
        print(f"特徴量間の相関性が高い特徴量を{str(len(drop_cols))}個抽出")
        self.df = self.df.drop(columns=drop_cols)
        self.drop_cols = list(set(self.drop_cols + drop_cols))

    def features_select(self):
        self._high_corr_features_drop()
        selected_features = list(set(self.init_features) - set(self.drop_cols))
        print(f"{str(len(self.init_features))} -> {str(len(selected_features))}")

        return selected_features

# %%
def null_importance_feature_select(df, features, n):
    null_imp_params = {
    'loss_function': 'Logloss',
    'eval_metric': 'Logloss',
    'learning_rate': 0.03,
    'num_boost_round': 100,
    'random_seed': cfg.seed,
    "od_type": "Iter"
} 

    tr_data = Pool(df[features], label=df["correct"], cat_features=["question"])  
    model = CatBoost(null_imp_params)
    model.fit(tr_data, verbose=100)
    fi_org = pd.DataFrame()
    fi_org["feature"] = features
    fi_org["importance"] = model.feature_importances_
    fi_org = fi_org.sort_values("feature", ignore_index=True)

    null_imps = []
    for i in range(10):
        print("null_imp", i)
        tr_data = Pool(df[features], label=df["correct"].sample(frac=1, random_state=i).values, cat_features=["question"])  
        model = CatBoost(null_imp_params)
        model.fit(tr_data, verbose=100)
        fi_tmp = pd.DataFrame()
        fi_tmp["feature"] = features
        fi_tmp["importance"] = model.feature_importances_
        null_imps.append(fi_tmp)
    null_imp = pd.concat(null_imps)
    null_imp_mean = null_imp.groupby("feature")["importance"].quantile(0.8).reset_index().sort_values("feature", ignore_index=True)
    fi_org["null_imp"] = null_imp_mean["importance"]
    fi_org["gain"] = np.log(1e-10 + fi_org["importance"] / (1 + fi_org["null_imp"]))
    selected_features = fi_org.sort_values("gain", ascending=False).head(n)["feature"].tolist()
    
    return selected_features

# %%
def run_train():
    oofs = []
    prev_features_df = None # 次のlevel_groupで特徴量を使うための保持データ。0-4は前のlevel_groupがないので初期値はNone
    for group in level_group_list:
        print(group)
        # データ読み込み
        train_sessions = pd.read_csv(cfg.prep_dir + f"train{group}_cleaned.csv")
        labels = pd.read_csv(cfg.prep_dir + f"train_labels{group}.csv")
        train = get_train_dataset(train_sessions, labels)

        # 一つ前のlevel_groupの特徴量を追加
        if prev_features_df is not None:
            train = train.merge(prev_features_df, on=["session_id"], how="left")
        else:
            pass

        # 前のlevel_groupのquestionパートの経過時間特徴量
        if group == "5-12":
            train["0-4_question_duration_time"] = train["5-12_elapsed_time_min"] - train["0-4_elapsed_time_max"]
            train["0-4_question_duration_index"] = train["5-12_index_min"] - train["0-4_index_max"]
        elif group == "13-22":
            train["5-12_question_duration_time"] = train["13-22_elapsed_time_min"] - train["5-12_elapsed_time_max"]
            train["5-12_question_duration_index"] = train["13-22_index_min"] - train["5-12_index_max"]

            train["5-12_0-4_pred_max_diff"] = train["5-12_pred_max"] - train["0-4_pred_max"]
            train["5-12_0-4_pred_min_diff"] = train["5-12_pred_min"] - train["0-4_pred_min"]
            train["5-12_0-4_pred_mean_diff"] = train["5-12_pred_mean"] - train["0-4_pred_mean"]
            train["5-12_0-4_pred_std_diff"] = train["5-12_pred_std"] - train["0-4_pred_std"]
            train["5-12_0-4_pred_maxmin_diff"] = train["5-12_pred_maxmin"] - train["0-4_pred_maxmin"]

        target = "correct"
        not_use_cols = [target, "session_id", "level_group"]
        features = [c for c in train.columns if c not in not_use_cols]

        # 特徴量選択
        if cfg.base_exp is None:
            features = FeaturesSelect(train, features).features_select()
            features = null_importance_feature_select(train, features, n=n_features[group])
        else:
            # 使用する特徴量の抽出
            features = pd.read_csv(cfg.output_dir + f"{cfg.base_exp}/fi_{group}.csv").head(cfg.n_features)["feature"].tolist()

        gkf = GroupKFold(n_splits=cfg.n_splits)
        fis = []
        
        oof_groups = []
        for i, (tr_idx, vl_idx) in enumerate(gkf.split(train[features], train[target], train["session_id"])):
            model_path = cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_model_{group}_{i}.cbm"
            
            print(f"fold : {i}")
            tr_x, tr_y = train.iloc[tr_idx][features], train.iloc[tr_idx][target]
            vl_x, vl_y = train.iloc[vl_idx][features], train.iloc[vl_idx][target]
            #tr_data = lgb.Dataset(tr_x, label=tr_y)
            #vl_data = lgb.Dataset(vl_x, label=vl_y)
            tr_data = Pool(tr_x, label=tr_y, cat_features=["question"])
            vl_data = Pool(vl_x, label=vl_y, cat_features=["question"])

            model = CatBoost(params)
            model.fit(tr_data, eval_set=vl_data, early_stopping_rounds=1000, verbose=100, use_best_model=True)

            # モデル出力
            model.save_model(model_path)
        
            # valid_pred
            oof_fold = train.iloc[vl_idx].copy()
            oof_fold["pred"] = model.predict(Pool(vl_x, cat_features=["question"]), prediction_type="Probability")[:,1]
            oof_groups.append(oof_fold)

            # 特徴量重要度
            fi_fold = pd.DataFrame()
            fi_fold["feature"] = features
            fi_fold["importance"] = model.feature_importances_
            fi_fold["fold"] = i
            fis.append(fi_fold)

        fi = pd.concat(fis)    
        fi = fi.groupby("feature")["importance"].mean().reset_index()
        fi = fi.sort_values("importance", ascending=False).reset_index(drop=True)
        fi.to_csv(cfg.output_dir + f"{cfg.exp_name}/fi_{group}.csv", index=False)

        oof_group = pd.concat(oof_groups)
        oofs.append(oof_group)

        # 次のlevel_groupで使う用に特徴量を保持
        prev_features_df = train.groupby("session_id").head(1).drop(columns=["question", "correct", "level_group"])

        # meta_featureの付与
        meta_df = oof_group.groupby("session_id")["pred"].agg(["mean", "max", "min", "std"]).reset_index()
        meta_df = meta_df.rename(columns={"mean":f"{group}_pred_mean", "max":f"{group}_pred_max", "min":f"{group}_pred_min", "std":f"{group}_pred_std"})
        meta_df[f"{group}_pred_maxmin"] = meta_df[f"{group}_pred_max"] - meta_df[f"{group}_pred_min"]
        prev_features_df = prev_features_df.merge(meta_df, on="session_id", how="left")

    # cv
    oof = pd.concat(oofs)
    best_threshold = calc_metrics(oof)
    cfg.best_threshold = best_threshold
    oof[["session_id", "question", "pred", "correct"]].to_csv(cfg.output_dir + f"{cfg.exp_name}/oof.csv.gz", compression="gzip", index=False)

# %%
def get_mock_iter_train():
    """trainデータのiter分割を適用したtest_sample
    """
    test = pd.read_csv(cfg.input_dir + "_old/test.csv")
    sub = pd.read_csv(cfg.input_dir + "_old/sample_submission.csv")
    sub["level_group"] = sub["session_level"].apply(lambda x: x.split("_")[-1])
    
    # groupbyでiter作るときにgroup_levelの順番が崩れないように
    test["level_group2"] = test["level_group"].str.replace("13-22", "6")
    sub["level_group2"] = sub["level_group"].str.replace("13-22", "6")

    tests = [df[1].drop(columns=["session_level", "level_group2"]).reset_index(drop=True) for df in test.groupby("level_group2")]
    subs = [df[1].drop(columns=["session_level", "level_group2"]).reset_index(drop=True) for df in sub.groupby("level_group2")]
    return zip(tests, subs)

def get_mock_iter_test():
    """testデータのiter分割を適用したtest_sample
    """
    test = pd.read_csv(cfg.input_dir + "_old/test.csv")
    sub = pd.read_csv(cfg.input_dir + "_old/sample_submission.csv")
    
    # groupbyでiter作るときにgroup_levelの順番が崩れないように
    test["session_level"] = test["session_level"].str.replace("13-22", "6")
    sub["session_level"] = sub["session_level"].str.replace("13-22", "6")

    tests = [df[1].drop(columns="session_level").reset_index(drop=True) for df in test.groupby("session_level")]
    subs = [df[1].drop(columns="session_level").reset_index(drop=True) for df in sub.groupby("session_level")]
    return zip(tests, subs)

# %%
def inference(mode):
    if mode == "local_cv":
        # time series apiを模したiterをモックとして用意する
        iter_test = get_mock_iter_test()
        start_time = time.time()
    elif mode == "kaggle_inf":
        env = jo_wilder_310.make_env()
        iter_test = env.iter_test()
        
    model_dict = {}
    features_dict = {}
    for g in level_group_list:
        if mode == "local_cv":
            model_paths = [cfg.output_dir + f"{cfg.exp_name}/{cfg.exp_name}_model_{g}_{i}.cbm" for i in range(cfg.n_splits)]
        elif mode == "kaggle_inf":
            model_paths = [f"/kaggle/input/jo-wilder-{cfg.exp_name}/{cfg.exp_name}_model_{g}_{i}.cbm" for i in range(cfg.n_splits)]
        models = []
        for i in range(cfg.n_splits):
            model = CatBoost()
            model.load_model(model_paths[i])
            models.append(model)
        model_dict[g] = models
        features_dict[g] = list(model.feature_importances_)
    need_create_features = features_dict["0-4"] + features_dict["5-12"] + features_dict["13-22"]
    not_drop_cols = ["0-4_elapsed_time_max", "0-4_index_max", "5-12_elapsed_time_max", "5-12_index_max", "13-22_elapsed_time_max", "13-22_index_max",
                     "0-4_elapsed_time_min", "0-4_index_min", "5-12_elapsed_time_min", "5-12_index_min", "13-22_elapsed_time_min", "13-22_index_min"]
    need_create_features = need_create_features + not_drop_cols
    need_create_features = list(set(need_create_features))
    
    prev_features_df = None
    for (test_sessions, sample_submission) in iter_test:
        level_group = test_sessions["level_group"].values[0]
        test = get_test_dataset(test_sessions, sample_submission, need_create_features=need_create_features)
        features = features_dict[level_group]
        preds = np.zeros(len(test))

        if level_group == "0-4":
            pass
        else:
            test = test.merge(prev_features_df, on=["session_id"], how="left")

        # 前のlevel_groupのquestionパートの経過時間特徴量
        if level_group == "5-12":
            test["0-4_question_duration_time"] = test["5-12_elapsed_time_min"] - test["0-4_elapsed_time_max"]
            test["0-4_question_duration_index"] = test["5-12_index_min"] - test["0-4_index_max"]
        elif level_group == "13-22":
            test["5-12_question_duration_time"] = test["13-22_elapsed_time_min"] - test["5-12_elapsed_time_max"]
            test["5-12_question_duration_index"] = test["13-22_index_min"] - test["5-12_index_max"]

            test["5-12_0-4_pred_max_diff"] = test["5-12_pred_max"] - test["0-4_pred_max"]
            test["5-12_0-4_pred_min_diff"] = test["5-12_pred_min"] - test["0-4_pred_min"]
            test["5-12_0-4_pred_mean_diff"] = test["5-12_pred_mean"] - test["0-4_pred_mean"]
            test["5-12_0-4_pred_std_diff"] = test["5-12_pred_std"] - test["0-4_pred_std"]
            test["5-12_0-4_pred_maxmin_diff"] = test["5-12_pred_maxmin"] - test["0-4_pred_maxmin"]

        prev_features_df = test.groupby("session_id").head(1).drop(columns=["question", "correct"])

        for i in range(cfg.n_splits):
            model = model_dict[level_group][i]
            preds += model.predict(Pool(test[features], cat_features=["question"]), prediction_type="Probability") / cfg.n_splits
        test["pred"] = preds
        preds = (preds>cfg.best_threshold).astype(int)
        sample_submission["correct"] = preds
        
        # meta_featureの付与
        meta_df = test.groupby("session_id")["pred"].agg(["mean", "max", "min", "std"]).reset_index()
        meta_df = meta_df.rename(columns={"mean":f"{level_group}_pred_mean", "max":f"{level_group}_pred_max", "min":f"{level_group}_pred_min", "std":f"{level_group}_pred_std"})
        meta_df[f"{level_group}_pred_maxmin"] = meta_df[f"{level_group}_pred_max"] - meta_df[f"{level_group}_pred_min"]
        prev_features_df = prev_features_df.merge(meta_df, on="session_id", how="left")

        if mode == "local_cv":
            print(sample_submission["correct"].values)
        elif mode == "kaggle_inf":
            env.predict(sample_submission)
    if mode == "local_cv":
        process_time = format(time.time() - start_time, ".1f")
        print("sample_inf処理時間 : ", process_time, "秒")

# %%
def valid_train_test_process_identity():
    iter_train = get_mock_iter_train()
    iter_test = get_mock_iter_test()

    print("train_iter")
    train_df_dict = {}
    train_features_dict = {}
    prev_features_df = None
    for (sessions, sub) in iter_train:
        group = sessions["level_group"].values[0]
        print(group)
        train = get_train_dataset(sessions, sub)
        if prev_features_df is not None:
            train = train.merge(prev_features_df, on=["session_id"], how="left")
        else:
            pass
            # 前のlevel_groupのquestionパートの経過時間特徴量
        if group == "5-12":
            train["0-4_question_duration_time"] = train["5-12_elapsed_time_min"] - train["0-4_elapsed_time_max"]
            train["0-4_question_duration_index"] = train["5-12_index_min"] - train["0-4_index_max"]
        elif group == "13-22":
            train["5-12_question_duration_time"] = train["13-22_elapsed_time_min"] - train["5-12_elapsed_time_max"]
            train["5-12_question_duration_index"] = train["13-22_index_min"] - train["5-12_index_max"]
        target = "correct"
        not_use_cols = [target, "session_id", "level_group"]
        features = [c for c in train.columns if c not in not_use_cols]
        train_df_dict[group] = train[["session_id"]+features].sort_values(["session_id", "question"], ignore_index=True)
        prev_features_df = train[["session_id"]+features].groupby("session_id").head(1).drop(columns="question")
        train_features_dict[group] = features


    print("test_iter")
    test_dfs_0_4 = []
    test_dfs_5_12 = []
    test_dfs_13_22 = []
    prev_features_df = None
    for (test_sessions, sample_submission) in iter_test:
        level_group = test_sessions["level_group"].values[0]
        session_id = test_sessions["session_id"].values[0]
        print(session_id, level_group)
        features = train_features_dict[level_group]
        test = get_test_dataset(test_sessions, sample_submission)

        if level_group == "0-4":
            pass
        else:
            test = test.merge(prev_features_df, on=["session_id"], how="left")

        # 前のlevel_groupのquestionパートの経過時間特徴量
        if level_group == "5-12":
            test["0-4_question_duration_time"] = test["5-12_elapsed_time_min"] - test["0-4_elapsed_time_max"]
            test["0-4_question_duration_index"] = test["5-12_index_min"] - test["0-4_index_max"]
        elif level_group == "13-22":
            test["5-12_question_duration_time"] = test["13-22_elapsed_time_min"] - test["5-12_elapsed_time_max"]
            test["5-12_question_duration_index"] = test["13-22_index_min"] - test["5-12_index_max"]
        target = "correct"
        not_use_cols = [target, "session_id", "level_group"]
        features = [c for c in test.columns if c not in not_use_cols]
        prev_features_df = test[["session_id"]+features].groupby("session_id").head(1).drop(columns="question")
        if level_group == "0-4":
            test_dfs_0_4.append(test[["session_id"]+features])
        elif level_group == "5-12":
            test_dfs_5_12.append(test[["session_id"]+features])
        elif level_group == "13-22":
            test_dfs_13_22.append(test[["session_id"]+features])
        

    test_dfs_0_4 = pd.concat(test_dfs_0_4, ignore_index=True).sort_values(["session_id", "question"], ignore_index=True)
    test_dfs_5_12 = pd.concat(test_dfs_5_12, ignore_index=True).sort_values(["session_id", "question"], ignore_index=True)
    test_dfs_13_22 = pd.concat(test_dfs_13_22, ignore_index=True).sort_values(["session_id", "question"], ignore_index=True)

    assert train_df_dict["0-4"][train_features_dict["0-4"]].equals(test_dfs_0_4[train_features_dict["0-4"]])
    assert train_df_dict["5-12"][train_features_dict["5-12"]].equals(test_dfs_5_12[train_features_dict["5-12"]])
    assert train_df_dict["13-22"][train_features_dict["13-22"]].equals(test_dfs_13_22[train_features_dict["13-22"]])

# %%
if cfg.mode == "local_cv":
    valid_train_test_process_identity()
    run_train()
inference(cfg.mode)
# Out:
# train_iter
# 0-4
# 5-12
# 13-22
# test_iter
# 20090109393214576 0-4
# 20090109393214576 5-12
# 20090109393214576 13-22
# 20090312143683264 0-4
# 20090312143683264 5-12
# 20090312143683264 13-22
# 20090312331414616 0-4
# 20090312331414616 5-12
# 20090312331414616 13-22
# 0-4
# 特徴量間の相関性が高い特徴量を2156個抽出
# 3871 -> 1715
# 0:	learn: 0.6690720	total: 346ms	remaining: 34.2s
# 99:	learn: 0.2761735	total: 10.8s	remaining: 0us
# null_imp 0
# 0:	learn: 0.6708405	total: 242ms	remaining: 23.9s
# 99:	learn: 0.3652607	total: 10s	remaining: 0us
# null_imp 1
# 0:	learn: 0.6708355	total: 247ms	remaining: 24.4s
# 99:	learn: 0.3653650	total: 10s	remaining: 0us
# null_imp 2
# 0:	learn: 0.6708455	total: 247ms	remaining: 24.4s
# 99:	learn: 0.3653208	total: 10.2s	remaining: 0us
# null_imp 3
# 0:	learn: 0.6708442	total: 239ms	remaining: 23.7s
# 99:	learn: 0.3652897	total: 10.2s	remaining: 0us
# null_imp 4
# 0:	learn: 0.6708441	total: 243ms	remaining: 24.1s
# 99:	learn: 0.3653093	total: 10.1s	remaining: 0us
# null_imp 5
# 0:	learn: 0.6708463	total: 243ms	remaining: 24.1s
# 99:	learn: 0.3654389	total: 10.2s	remaining: 0us
# null_imp 6
# 0:	learn: 0.6708538	total: 238ms	remaining: 23.6s
# 99:	learn: 0.3654144	total: 10.2s	remaining: 0us
# null_imp 7
# 0:	learn: 0.6708381	total: 250ms	remaining: 24.8s
# 99:	learn: 0.3653536	total: 10.2s	remaining: 0us
# null_imp 8
# 0:	learn: 0.6708338	total: 244ms	remaining: 24.2s
# 99:	learn: 0.3653479	total: 10.1s	remaining: 0us
# null_imp 9
# 0:	learn: 0.6708307	total: 243ms	remaining: 24.1s
# 99:	learn: 0.3653720	total: 10.1s	remaining: 0us
# fold : 0
# 0:	learn: 0.6618476	test: 0.6620773	best: 0.6620773 (0)	total: 102ms	remaining: 16m 55s
# 100:	learn: 0.2724514	test: 0.2822296	best: 0.2822296 (100)	total: 5s	remaining: 8m 10s
# 200:	learn: 0.2621871	test: 0.2764108	best: 0.2764108 (200)	total: 10s	remaining: 8m 8s
# 300:	learn: 0.2559426	test: 0.2743204	best: 0.2743086 (292)	total: 14.9s	remaining: 7m 58s
# 400:	learn: 0.2501513	test: 0.2733203	best: 0.2733203 (400)	total: 19.6s	remaining: 7m 49s
# 500:	learn: 0.2447832	test: 0.2727438	best: 0.2727438 (500)	total: 24.3s	remaining: 7m 40s
# 600:	learn: 0.2397140	test: 0.2724658	best: 0.2724450 (562)	total: 29s	remaining: 7m 33s
# 700:	learn: 0.2345642	test: 0.2719485	best: 0.2719330 (699)	total: 33.8s	remaining: 7m 28s
# 800:	learn: 0.2301411	test: 0.2717520	best: 0.2717281 (795)	total: 38.5s	remaining: 7m 22s
# 900:	learn: 0.2255510	test: 0.2714882	best: 0.2714882 (900)	total: 43.4s	remaining: 7m 18s
# 1000:	learn: 0.2212985	test: 0.2712946	best: 0.2712336 (988)	total: 48.2s	remaining: 7m 12s
# 1100:	learn: 0.2171021	test: 0.2711691	best: 0.2711404 (1094)	total: 52.9s	remaining: 7m 7s
# 1200:	learn: 0.2130997	test: 0.2709277	best: 0.2709272 (1199)	total: 57.8s	remaining: 7m 3s
# 1300:	learn: 0.2092922	test: 0.2709511	best: 0.2708833 (1241)	total: 1m 2s	remaining: 6m 58s
# 1400:	learn: 0.2055036	test: 0.2710273	best: 0.2708833 (1241)	total: 1m 7s	remaining: 6m 53s
# 1500:	learn: 0.2017972	test: 0.2710717	best: 0.2708833 (1241)	total: 1m 12s	remaining: 6m 48s
# 1600:	learn: 0.1984554	test: 0.2711961	best: 0.2708833 (1241)	total: 1m 16s	remaining: 6m 43s
# 1700:	learn: 0.1951895	test: 0.2711930	best: 0.2708833 (1241)	total: 1m 21s	remaining: 6m 38s
# 1800:	learn: 0.1917528	test: 0.2713698	best: 0.2708833 (1241)	total: 1m 26s	remaining: 6m 33s
# 1900:	learn: 0.1887163	test: 0.2715307	best: 0.2708833 (1241)	total: 1m 31s	remaining: 6m 28s
# 2000:	learn: 0.1856254	test: 0.2714375	best: 0.2708833 (1241)	total: 1m 35s	remaining: 6m 23s
# 2100:	learn: 0.1825058	test: 0.2712599	best: 0.2708833 (1241)	total: 1m 40s	remaining: 6m 19s
# 2200:	learn: 0.1796664	test: 0.2714519	best: 0.2708833 (1241)	total: 1m 45s	remaining: 6m 14s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2708832592
# bestIteration = 1241
#
# Shrink model to first 1242 iterations.
# fold : 1
# 0:	learn: 0.6605079	test: 0.6605365	best: 0.6605365 (0)	total: 108ms	remaining: 17m 59s
# 100:	learn: 0.2728396	test: 0.2740476	best: 0.2740476 (100)	total: 4.96s	remaining: 8m 5s
# 200:	learn: 0.2627355	test: 0.2695519	best: 0.2695519 (200)	total: 9.84s	remaining: 7m 59s
# 300:	learn: 0.2567248	test: 0.2677320	best: 0.2677320 (300)	total: 14.6s	remaining: 7m 50s
# 400:	learn: 0.2512203	test: 0.2664212	best: 0.2664212 (400)	total: 19.4s	remaining: 7m 43s
# 500:	learn: 0.2451959	test: 0.2657774	best: 0.2657619 (499)	total: 24.1s	remaining: 7m 36s
# 600:	learn: 0.2396289	test: 0.2654588	best: 0.2654541 (598)	total: 28.8s	remaining: 7m 30s
# 700:	learn: 0.2344972	test: 0.2652330	best: 0.2652125 (671)	total: 33.6s	remaining: 7m 25s
# 800:	learn: 0.2297347	test: 0.2650161	best: 0.2650125 (797)	total: 38.4s	remaining: 7m 20s
# 900:	learn: 0.2252581	test: 0.2650780	best: 0.2650125 (797)	total: 43.1s	remaining: 7m 15s
# 1000:	learn: 0.2207829	test: 0.2650632	best: 0.2650125 (797)	total: 47.9s	remaining: 7m 10s
# 1100:	learn: 0.2168675	test: 0.2651381	best: 0.2650028 (1029)	total: 52.8s	remaining: 7m 6s
# 1200:	learn: 0.2129122	test: 0.2651003	best: 0.2650028 (1029)	total: 57.6s	remaining: 7m 1s
# 1300:	learn: 0.2092168	test: 0.2652506	best: 0.2650028 (1029)	total: 1m 2s	remaining: 6m 56s
# 1400:	learn: 0.2053959	test: 0.2653356	best: 0.2650028 (1029)	total: 1m 7s	remaining: 6m 51s
# 1500:	learn: 0.2018353	test: 0.2655465	best: 0.2650028 (1029)	total: 1m 11s	remaining: 6m 46s

# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2600718655
# bestIteration = 1273
#
# Shrink model to first 1274 iterations.
# fold : 3
# 0:	learn: 0.6613119	test: 0.6613061	best: 0.6613061 (0)	total: 105ms	remaining: 17m 30s
# 100:	learn: 0.2729058	test: 0.2803954	best: 0.2803954 (100)	total: 5.07s	remaining: 8m 16s
# 200:	learn: 0.2617250	test: 0.2744666	best: 0.2744666 (200)	total: 10s	remaining: 8m 9s
# 300:	learn: 0.2553356	test: 0.2727025	best: 0.2727025 (300)	total: 14.9s	remaining: 7m 59s
# 400:	learn: 0.2500609	test: 0.2716879	best: 0.2716840 (398)	total: 19.7s	remaining: 7m 50s
# 500:	learn: 0.2440082	test: 0.2706861	best: 0.2706544 (494)	total: 24.4s	remaining: 7m 43s
# 600:	learn: 0.2383568	test: 0.2699222	best: 0.2699222 (600)	total: 29.2s	remaining: 7m 37s
# 700:	learn: 0.2333417	test: 0.2695839	best: 0.2695018 (684)	total: 34s	remaining: 7m 30s
# 800:	learn: 0.2285405	test: 0.2693340	best: 0.2693146 (796)	total: 38.7s	remaining: 7m 24s
# 900:	learn: 0.2238509	test: 0.2693324	best: 0.2692992 (803)	total: 43.5s	remaining: 7m 18s
# 1000:	learn: 0.2193943	test: 0.2693187	best: 0.2692502 (942)	total: 48.2s	remaining: 7m 13s
# 1100:	learn: 0.2153024	test: 0.2693047	best: 0.2692502 (942)	total: 53s	remaining: 7m 8s
# 1200:	learn: 0.2113455	test: 0.2693886	best: 0.2692502 (942)	total: 57.9s	remaining: 7m 4s
# 1300:	learn: 0.2074911	test: 0.2694816	best: 0.2692502 (942)	total: 1m 2s	remaining: 6m 58s
# 1400:	learn: 0.2037202	test: 0.2695791	best: 0.2692502 (942)	total: 1m 7s	remaining: 6m 53s
# 1500:	learn: 0.2001615	test: 0.2697491	best: 0.2692502 (942)	total: 1m 12s	remaining: 6m 48s
# 1600:	learn: 0.1967508	test: 0.2699856	best: 0.2692502 (942)	total: 1m 16s	remaining: 6m 43s
# 1700:	learn: 0.1934405	test: 0.2699442	best: 0.2692502 (942)	total: 1m 21s	remaining: 6m 38s
# 1800:	learn: 0.1902459	test: 0.2699895	best: 0.2692502 (942)	total: 1m 26s	remaining: 6m 33s
# 1900:	learn: 0.1870089	test: 0.2700992	best: 0.2692502 (942)	total: 1m 31s	remaining: 6m 28s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2692502357
# bestIteration = 942
#
# Shrink model to first 943 iterations.
# fold : 4
# 0:	learn: 0.6632907	test: 0.6634904	best: 0.6634904 (0)	total: 102ms	remaining: 16m 57s
# 100:	learn: 0.2747788	test: 0.2786530	best: 0.2786530 (100)	total: 5.04s	remaining: 8m 13s
# 200:	learn: 0.2641026	test: 0.2705436	best: 0.2705436 (200)	total: 10s	remaining: 8m 9s
# 300:	learn: 0.2579935	test: 0.2677325	best: 0.2677325 (300)	total: 14.8s	remaining: 7m 58s
# 400:	learn: 0.2525895	test: 0.2662692	best: 0.2662692 (400)	total: 19.6s	remaining: 7m 50s
# 500:	learn: 0.2470076	test: 0.2651284	best: 0.2651276 (499)	total: 24.4s	remaining: 7m 41s
# 600:	learn: 0.2414920	test: 0.2643359	best: 0.2643111 (597)	total: 29s	remaining: 7m 34s
# 700:	learn: 0.2361755	test: 0.2634938	best: 0.2634936 (699)	total: 33.8s	remaining: 7m 27s
# 800:	learn: 0.2313708	test: 0.2632915	best: 0.2632697 (796)	total: 38.5s	remaining: 7m 22s
# 900:	learn: 0.2269290	test: 0.2630007	best: 0.2629442 (877)	total: 43.4s	remaining: 7m 17s
# 1000:	learn: 0.2227362	test: 0.2628520	best: 0.2628520 (1000)	total: 48.1s	remaining: 7m 12s
# 1100:	learn: 0.2186173	test: 0.2627237	best: 0.2627237 (1100)	total: 53s	remaining: 7m 8s
# 1200:	learn: 0.2148726	test: 0.2627248	best: 0.2626887 (1163)	total: 57.7s	remaining: 7m 3s
# 1300:	learn: 0.2113016	test: 0.2629079	best: 0.2626632 (1217)	total: 1m 2s	remaining: 6m 57s
# 1400:	learn: 0.2076319	test: 0.2627039	best: 0.2626632 (1217)	total: 1m 7s	remaining: 6m 52s
# 1500:	learn: 0.2039912	test: 0.2626650	best: 0.2626596 (1488)	total: 1m 11s	remaining: 6m 47s
# 1600:	learn: 0.2006396	test: 0.2626537	best: 0.2626352 (1593)	total: 1m 16s	remaining: 6m 42s
# 1700:	learn: 0.1971750	test: 0.2627738	best: 0.2626352 (1593)	total: 1m 21s	remaining: 6m 37s
# 1800:	learn: 0.1939293	test: 0.2627043	best: 0.2626352 (1593)	total: 1m 26s	remaining: 6m 33s
# 1900:	learn: 0.1908165	test: 0.2628839	best: 0.2626352 (1593)	total: 1m 31s	remaining: 6m 28s
# 2000:	learn: 0.1877129	test: 0.2629450	best: 0.2626352 (1593)	total: 1m 35s	remaining: 6m 23s
# 2100:	learn: 0.1846795	test: 0.2629931	best: 0.2626352 (1593)	total: 1m 40s	remaining: 6m 18s
# 2200:	learn: 0.1816977	test: 0.2631737	best: 0.2626352 (1593)	total: 1m 45s	remaining: 6m 14s
# 2300:	learn: 0.1788344	test: 0.2633569	best: 0.2626352 (1593)	total: 1m 50s	remaining: 6m 9s
# 2400:	learn: 0.1761057	test: 0.2634908	best: 0.2626352 (1593)	total: 1m 55s	remaining: 6m 4s
# 2500:	learn: 0.1731283	test: 0.2636996	best: 0.2626352 (1593)	total: 1m 59s	remaining: 5m 59s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2626351848
# bestIteration = 1593
#
# Shrink model to first 1594 iterations.
# 5-12
# 特徴量間の相関性が高い特徴量を5630個抽出
# 11090 -> 5460
# 0:	learn: 0.6888476	total: 1.14s	remaining: 1m 52s
# 99:	learn: 0.5462833	total: 1m	remaining: 0us
# null_imp 0
# 0:	learn: 0.6904018	total: 975ms	remaining: 1m 36s
# 99:	learn: 0.6469134	total: 52.6s	remaining: 0us
# null_imp 1
# 0:	learn: 0.6904030	total: 999ms	remaining: 1m 38s
# 99:	learn: 0.6469369	total: 52.2s	remaining: 0us
# null_imp 2
# 0:	learn: 0.6904019	total: 982ms	remaining: 1m 37s
# 99:	learn: 0.6469153	total: 52.2s	remaining: 0us
# null_imp 3
# 0:	learn: 0.6904024	total: 970ms	remaining: 1m 36s
# 99:	learn: 0.6468770	total: 52.6s	remaining: 0us
# null_imp 4
# 0:	learn: 0.6904006	total: 978ms	remaining: 1m 36s
# 99:	learn: 0.6469022	total: 51.8s	remaining: 0us
# null_imp 5
# 0:	learn: 0.6904029	total: 984ms	remaining: 1m 37s
# 99:	learn: 0.6469177	total: 52.5s	remaining: 0us
# null_imp 6
# 0:	learn: 0.6904034	total: 975ms	remaining: 1m 36s
# 99:	learn: 0.6469215	total: 52.6s	remaining: 0us
# null_imp 7
# 0:	learn: 0.6904010	total: 978ms	remaining: 1m 36s
# 99:	learn: 0.6469242	total: 52.5s	remaining: 0us
# null_imp 8
# 0:	learn: 0.6903996	total: 980ms	remaining: 1m 37s
# 99:	learn: 0.6468966	total: 52.8s	remaining: 0us
# null_imp 9
# 0:	learn: 0.6903996	total: 980ms	remaining: 1m 37s
# 99:	learn: 0.6469484	total: 52s	remaining: 0us
# fold : 0
# 0:	learn: 0.6850627	test: 0.6850666	best: 0.6850666 (0)	total: 217ms	remaining: 36m 5s
# 100:	learn: 0.5451145	test: 0.5478002	best: 0.5478002 (100)	total: 13.4s	remaining: 21m 54s
# 200:	learn: 0.5372217	test: 0.5414774	best: 0.5414774 (200)	total: 27.2s	remaining: 22m 7s
# 300:	learn: 0.5329629	test: 0.5392711	best: 0.5392711 (300)	total: 39.8s	remaining: 21m 21s
# 400:	learn: 0.5293803	test: 0.5378676	best: 0.5378676 (400)	total: 52.2s	remaining: 20m 49s
# 500:	learn: 0.5255147	test: 0.5371986	best: 0.5371845 (494)	total: 1m 4s	remaining: 20m 23s
# 600:	learn: 0.5218579	test: 0.5365437	best: 0.5365437 (600)	total: 1m 16s	remaining: 20m 1s
# 700:	learn: 0.5184809	test: 0.5360902	best: 0.5360902 (700)	total: 1m 29s	remaining: 19m 45s
# 800:	learn: 0.5153292	test: 0.5359194	best: 0.5359194 (800)	total: 1m 41s	remaining: 19m 27s
# 900:	learn: 0.5124304	test: 0.5356864	best: 0.5356806 (896)	total: 1m 54s	remaining: 19m 11s
# 1000:	learn: 0.5097101	test: 0.5354067	best: 0.5354067 (1000)	total: 2m 6s	remaining: 18m 55s
# 1100:	learn: 0.5072310	test: 0.5351746	best: 0.5351705 (1099)	total: 2m 18s	remaining: 18m 38s
# 1200:	learn: 0.5048769	test: 0.5350350	best: 0.5350318 (1199)	total: 2m 30s	remaining: 18m 22s
# 1300:	learn: 0.5025546	test: 0.5348526	best: 0.5348464 (1297)	total: 2m 42s	remaining: 18m 8s
# 1400:	learn: 0.5003504	test: 0.5347513	best: 0.5347416 (1397)	total: 2m 55s	remaining: 17m 55s
# 4100:	learn: 0.4612280	test: 0.5344349	best: 0.5343710 (3709)	total: 8m 26s	remaining: 12m 8s
# 4200:	learn: 0.4601355	test: 0.5344421	best: 0.5343710 (3709)	total: 8m 38s	remaining: 11m 55s
# 4300:	learn: 0.4589945	test: 0.5344391	best: 0.5343710 (3709)	total: 8m 51s	remaining: 11m 43s
# 4400:	learn: 0.4578872	test: 0.5344422	best: 0.5343710 (3709)	total: 9m 3s	remaining: 11m 30s
# 4500:	learn: 0.4568153	test: 0.5344017	best: 0.5343710 (3709)	total: 9m 15s	remaining: 11m 18s
# 4600:	learn: 0.4557334	test: 0.5344354	best: 0.5343710 (3709)	total: 9m 27s	remaining: 11m 6s
# 4700:	learn: 0.4546884	test: 0.5344063	best: 0.5343710 (3709)	total: 9m 40s	remaining: 10m 53s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.5343710054
# bestIteration = 3709
#
# Shrink model to first 3710 iterations.
# fold : 3
# 0:	learn: 0.6848666	test: 0.6848461	best: 0.6848461 (0)	total: 211ms	remaining: 35m 13s
# 100:	learn: 0.5452833	test: 0.5465044	best: 0.5465044 (100)	total: 13.3s	remaining: 21m 44s
# 200:	learn: 0.5372323	test: 0.5405837	best: 0.5405837 (200)	total: 26.8s	remaining: 21m 44s
# 300:	learn: 0.5330558	test: 0.5384648	best: 0.5384648 (300)	total: 39.6s	remaining: 21m 15s
# 400:	learn: 0.5295161	test: 0.5372349	best: 0.5372349 (400)	total: 52s	remaining: 20m 44s
# 500:	learn: 0.5255895	test: 0.5363554	best: 0.5363554 (500)	total: 1m 4s	remaining: 20m 18s
# 600:	learn: 0.5217937	test: 0.5359991	best: 0.5359763 (577)	total: 1m 16s	remaining: 19m 57s
# 700:	learn: 0.5184135	test: 0.5356340	best: 0.5356340 (700)	total: 1m 28s	remaining: 19m 39s
# 800:	learn: 0.5153505	test: 0.5353567	best: 0.5353526 (797)	total: 1m 41s	remaining: 19m 21s
# 900:	learn: 0.5124539	test: 0.5350099	best: 0.5350055 (898)	total: 1m 53s	remaining: 19m 7s
# 1000:	learn: 0.5098103	test: 0.5347306	best: 0.5347285 (999)	total: 2m 5s	remaining: 18m 51s
# 1100:	learn: 0.5072582	test: 0.5346474	best: 0.5346263 (1086)	total: 2m 18s	remaining: 18m 35s
# 1200:	learn: 0.5048420	test: 0.5344069	best: 0.5344069 (1200)	total: 2m 30s	remaining: 18m 20s
# 1300:	learn: 0.5026015	test: 0.5343517	best: 0.5343408 (1294)	total: 2m 42s	remaining: 18m 7s
# 1400:	learn: 0.5004040	test: 0.5341600	best: 0.5341600 (1400)	total: 2m 54s	remaining: 17m 52s
# 1500:	learn: 0.4982562	test: 0.5340066	best: 0.5340039 (1499)	total: 3m 6s	remaining: 17m 38s
# 1600:	learn: 0.4961698	test: 0.5337160	best: 0.5337080 (1598)	total: 3m 19s	remaining: 17m 24s
# 1700:	learn: 0.4942135	test: 0.5336265	best: 0.5336228 (1677)	total: 3m 31s	remaining: 17m 11s
# 4400:	learn: 0.4566738	test: 0.5331730	best: 0.5330787 (3948)	total: 9m 6s	remaining: 11m 35s
# 4500:	learn: 0.4555831	test: 0.5332377	best: 0.5330787 (3948)	total: 9m 19s	remaining: 11m 23s
# 4600:	learn: 0.4544952	test: 0.5332878	best: 0.5330787 (3948)	total: 9m 31s	remaining: 11m 11s
# 4700:	learn: 0.4533757	test: 0.5332739	best: 0.5330787 (3948)	total: 9m 44s	remaining: 10m 58s
# 4800:	learn: 0.4523132	test: 0.5332938	best: 0.5330787 (3948)	total: 9m 56s	remaining: 10m 46s
# 4900:	learn: 0.4512796	test: 0.5333255	best: 0.5330787 (3948)	total: 10m 9s	remaining: 10m 33s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.5330787145
# bestIteration = 3948
#
# Shrink model to first 3949 iterations.
# fold : 4
# 0:	learn: 0.6849373	test: 0.6850337	best: 0.6850337 (0)	total: 230ms	remaining: 38m 18s
# 100:	learn: 0.5451274	test: 0.5477862	best: 0.5477862 (100)	total: 13.4s	remaining: 21m 53s
# 200:	learn: 0.5370954	test: 0.5418392	best: 0.5418392 (200)	total: 26s	remaining: 21m 8s
# 300:	learn: 0.5327681	test: 0.5397674	best: 0.5397674 (300)	total: 38.7s	remaining: 20m 47s
# 400:	learn: 0.5291586	test: 0.5384541	best: 0.5384541 (400)	total: 51.3s	remaining: 20m 26s
# 500:	learn: 0.5252678	test: 0.5375329	best: 0.5375329 (500)	total: 1m 3s	remaining: 20m 5s
# 600:	learn: 0.5215243	test: 0.5370310	best: 0.5370184 (586)	total: 1m 16s	remaining: 19m 48s
# 700:	learn: 0.5181326	test: 0.5366535	best: 0.5366419 (695)	total: 1m 28s	remaining: 19m 32s
# 800:	learn: 0.5150339	test: 0.5364402	best: 0.5364402 (800)	total: 1m 40s	remaining: 19m 17s
# 900:	learn: 0.5122098	test: 0.5362354	best: 0.5362284 (899)	total: 1m 53s	remaining: 19m 1s
# 1000:	learn: 0.5093907	test: 0.5359866	best: 0.5359866 (1000)	total: 2m 5s	remaining: 18m 49s
# 1100:	learn: 0.5068474	test: 0.5357122	best: 0.5357122 (1100)	total: 2m 17s	remaining: 18m 34s
# 1200:	learn: 0.5043359	test: 0.5355228	best: 0.5355146 (1191)	total: 2m 30s	remaining: 18m 20s
# 1300:	learn: 0.5020490	test: 0.5354164	best: 0.5354164 (1300)	total: 2m 42s	remaining: 18m 8s
# 1400:	learn: 0.4997810	test: 0.5352753	best: 0.5352753 (1400)	total: 2m 55s	remaining: 17m 55s
# 1500:	learn: 0.4976129	test: 0.5351823	best: 0.5351783 (1488)	total: 3m 7s	remaining: 17m 41s
# 1600:	learn: 0.4956284	test: 0.5350560	best: 0.5350560 (1600)	total: 3m 19s	remaining: 17m 28s
# 1700:	learn: 0.4937052	test: 0.5349645	best: 0.5349645 (1700)	total: 3m 32s	remaining: 17m 16s
# 1800:	learn: 0.4918518	test: 0.5348800	best: 0.5348710 (1792)	total: 3m 45s	remaining: 17m 4s
# 99:	learn: 0.5987584	total: 1m 12s	remaining: 0us
# null_imp 2
# 0:	learn: 0.6874390	total: 1.69s	remaining: 2m 46s
# 99:	learn: 0.5987913	total: 1m 12s	remaining: 0us
# null_imp 3
# 0:	learn: 0.6874458	total: 1.67s	remaining: 2m 45s
# 99:	learn: 0.5987754	total: 1m 11s	remaining: 0us
# null_imp 4
# 0:	learn: 0.6874414	total: 1.78s	remaining: 2m 56s
# 99:	learn: 0.5987953	total: 1m 13s	remaining: 0us
# null_imp 5
# 0:	learn: 0.6874460	total: 1.66s	remaining: 2m 44s
# 99:	learn: 0.5988337	total: 1m 11s	remaining: 0us
# null_imp 6
# 0:	learn: 0.6874440	total: 1.76s	remaining: 2m 54s
# 99:	learn: 0.5987547	total: 1m 13s	remaining: 0us
# null_imp 7
# 0:	learn: 0.6874458	total: 1.78s	remaining: 2m 56s
# 99:	learn: 0.5987620	total: 1m 12s	remaining: 0us
# null_imp 8
# 0:	learn: 0.6874435	total: 1.78s	remaining: 2m 56s
# 99:	learn: 0.5988148	total: 1m 12s	remaining: 0us
# null_imp 9
# 0:	learn: 0.6874364	total: 1.7s	remaining: 2m 47s
# 99:	learn: 0.5987810	total: 1m 11s	remaining: 0us
# fold : 0
# 0:	learn: 0.6803885	test: 0.6806018	best: 0.6806018 (0)	total: 188ms	remaining: 31m 17s
# 100:	learn: 0.5088395	test: 0.5170985	best: 0.5170985 (100)	total: 9.47s	remaining: 15m 28s
# 200:	learn: 0.5015215	test: 0.5127947	best: 0.5127947 (200)	total: 17.7s	remaining: 14m 24s
# 300:	learn: 0.4973577	test: 0.5116053	best: 0.5116051 (299)	total: 25.7s	remaining: 13m 49s
# 400:	learn: 0.4931691	test: 0.5104527	best: 0.5104480 (398)	total: 33.8s	remaining: 13m 28s
# 500:	learn: 0.4883756	test: 0.5095604	best: 0.5095604 (500)	total: 42s	remaining: 13m 15s
# 600:	learn: 0.4837239	test: 0.5089798	best: 0.5089739 (591)	total: 49.9s	remaining: 13m
# 700:	learn: 0.4794749	test: 0.5086007	best: 0.5085967 (696)	total: 58s	remaining: 12m 49s
# 800:	learn: 0.4755552	test: 0.5083859	best: 0.5083859 (800)	total: 1m 5s	remaining: 12m 36s
# 900:	learn: 0.4717979	test: 0.5081997	best: 0.5081914 (897)	total: 1m 13s	remaining: 12m 26s
# 1000:	learn: 0.4681347	test: 0.5080544	best: 0.5080452 (996)	total: 1m 21s	remaining: 12m 16s
# 1100:	learn: 0.4645002	test: 0.5077432	best: 0.5077432 (1100)	total: 1m 30s	remaining: 12m 8s
# 1200:	learn: 0.4611617	test: 0.5077072	best: 0.5076881 (1192)	total: 1m 38s	remaining: 11m 59s
# 1300:	learn: 0.4578819	test: 0.5074392	best: 0.5074383 (1299)	total: 1m 46s	remaining: 11m 50s
# 1400:	learn: 0.4545653	test: 0.5070659	best: 0.5070543 (1398)	total: 1m 54s	remaining: 11m 41s
# 4100:	learn: 0.3900875	test: 0.5058700	best: 0.5055550 (3622)	total: 5m 31s	remaining: 7m 57s
# 4200:	learn: 0.3881891	test: 0.5058084	best: 0.5055550 (3622)	total: 5m 39s	remaining: 7m 49s
# 4300:	learn: 0.3862927	test: 0.5058111	best: 0.5055550 (3622)	total: 5m 47s	remaining: 7m 40s
# 4400:	learn: 0.3844647	test: 0.5059106	best: 0.5055550 (3622)	total: 5m 55s	remaining: 7m 32s
# 4500:	learn: 0.3827470	test: 0.5060401	best: 0.5055550 (3622)	total: 6m 3s	remaining: 7m 24s
# 4600:	learn: 0.3809612	test: 0.5060962	best: 0.5055550 (3622)	total: 6m 11s	remaining: 7m 16s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.5055550058
# bestIteration = 3622
#
# Shrink model to first 3623 iterations.
# fold : 1
# 0:	learn: 0.6822894	test: 0.6824259	best: 0.6824259 (0)	total: 178ms	remaining: 29m 38s
# 100:	learn: 0.5119300	test: 0.5076431	best: 0.5076431 (100)	total: 9.13s	remaining: 14m 54s
# 200:	learn: 0.5039229	test: 0.5029128	best: 0.5029128 (200)	total: 18.1s	remaining: 14m 44s
# 300:	learn: 0.4994146	test: 0.5014817	best: 0.5014817 (300)	total: 26.3s	remaining: 14m 7s
# 400:	learn: 0.4950734	test: 0.5006041	best: 0.5006041 (400)	total: 34.3s	remaining: 13m 40s
# 500:	learn: 0.4901366	test: 0.4999810	best: 0.4999753 (499)	total: 42.2s	remaining: 13m 20s
# 600:	learn: 0.4853022	test: 0.4996285	best: 0.4996149 (589)	total: 50.2s	remaining: 13m 4s
# 700:	learn: 0.4810457	test: 0.4993067	best: 0.4992817 (690)	total: 58.3s	remaining: 12m 52s
# 800:	learn: 0.4769487	test: 0.4992307	best: 0.4991674 (771)	total: 1m 6s	remaining: 12m 41s
# 900:	learn: 0.4730397	test: 0.4989811	best: 0.4989707 (896)	total: 1m 14s	remaining: 12m 29s
# 1000:	learn: 0.4692215	test: 0.4986924	best: 0.4986920 (996)	total: 1m 22s	remaining: 12m 19s
# 1100:	learn: 0.4657871	test: 0.4985582	best: 0.4984769 (1077)	total: 1m 30s	remaining: 12m 8s
# 1200:	learn: 0.4624400	test: 0.4982664	best: 0.4982664 (1200)	total: 1m 38s	remaining: 11m 59s
# 1300:	learn: 0.4589864	test: 0.4981934	best: 0.4981123 (1246)	total: 1m 46s	remaining: 11m 50s
# 1400:	learn: 0.4558485	test: 0.4980627	best: 0.4980627 (1400)	total: 1m 54s	remaining: 11m 41s
# 1500:	learn: 0.4527582	test: 0.4979944	best: 0.4979589 (1472)	total: 2m 2s	remaining: 11m 32s
# 1600:	learn: 0.4498583	test: 0.4979211	best: 0.4979180 (1598)	total: 2m 10s	remaining: 11m 23s
# 1700:	learn: 0.4470141	test: 0.4978393	best: 0.4978298 (1644)	total: 2m 18s	remaining: 11m 14s
# 1800:	learn: 0.4441940	test: 0.4977113	best: 0.4976619 (1769)	total: 2m 26s	remaining: 11m 5s
# 1900:	learn: 0.4415400	test: 0.4978003	best: 0.4976619 (1769)	total: 2m 34s	remaining: 10m 57s
# 2000:	learn: 0.4389983	test: 0.4976281	best: 0.4976260 (1997)	total: 2m 42s	remaining: 10m 48s
# 2100:	learn: 0.4364814	test: 0.4977146	best: 0.4976244 (2002)	total: 2m 50s	remaining: 10m 40s
# 2200:	learn: 0.4339240	test: 0.4976386	best: 0.4976191 (2196)	total: 2m 58s	remaining: 10m 31s
# 2300:	learn: 0.4315247	test: 0.4976406	best: 0.4976063 (2280)	total: 3m 6s	remaining: 10m 22s
# 2400:	learn: 0.4292967	test: 0.4976877	best: 0.4976063 (2280)	total: 3m 14s	remaining: 10m 14s
# 2500:	learn: 0.4269554	test: 0.4977667	best: 0.4976063 (2280)	total: 3m 22s	remaining: 10m 6s
# 2600:	learn: 0.4247480	test: 0.4978026	best: 0.4976063 (2280)	total: 3m 30s	remaining: 9m 58s
# 2700:	learn: 0.4225178	test: 0.4978945	best: 0.4976063 (2280)	total: 3m 38s	remaining: 9m 50s
# 2800:	learn: 0.4203617	test: 0.4979429	best: 0.4976063 (2280)	total: 3m 46s	remaining: 9m 42s
# 2900:	learn: 0.4182398	test: 0.4978939	best: 0.4976063 (2280)	total: 3m 54s	remaining: 9m 33s
# 3000:	learn: 0.4159268	test: 0.4978566	best: 0.4976063 (2280)	total: 4m 2s	remaining: 9m 26s
# 3100:	learn: 0.4137652	test: 0.4979271	best: 0.4976063 (2280)	total: 4m 11s	remaining: 9m 19s
# 3200:	learn: 0.4116950	test: 0.4980009	best: 0.4976063 (2280)	total: 4m 19s	remaining: 9m 11s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.497606253
# bestIteration = 2280
#
# Shrink model to first 2281 iterations.
# fold : 2
# 0:	learn: 0.6803460	test: 0.6801984	best: 0.6801984 (0)	total: 171ms	remaining: 28m 29s
# 100:	learn: 0.5110788	test: 0.5098888	best: 0.5098888 (100)	total: 9.22s	remaining: 15m 4s
# 200:	learn: 0.5039934	test: 0.5055329	best: 0.5055329 (200)	total: 17.9s	remaining: 14m 32s
# 300:	learn: 0.4992833	test: 0.5036468	best: 0.5036468 (300)	total: 26.1s	remaining: 14m 1s
# 400:	learn: 0.4952564	test: 0.5029660	best: 0.5029487 (394)	total: 34s	remaining: 13m 34s
# 500:	learn: 0.4902918	test: 0.5022673	best: 0.5022594 (498)	total: 41.9s	remaining: 13m 14s
# 600:	learn: 0.4857372	test: 0.5018672	best: 0.5018672 (600)	total: 49.7s	remaining: 12m 57s
# 700:	learn: 0.4813228	test: 0.5011771	best: 0.5011771 (700)	total: 57.9s	remaining: 12m 47s
# 800:	learn: 0.4772248	test: 0.5007314	best: 0.5007284 (796)	total: 1m 5s	remaining: 12m 35s
# 900:	learn: 0.4734860	test: 0.5004100	best: 0.5004088 (899)	total: 1m 13s	remaining: 12m 23s
# 1000:	learn: 0.4697360	test: 0.5000674	best: 0.5000674 (1000)	total: 1m 21s	remaining: 12m 13s
# 1100:	learn: 0.4661414	test: 0.4996544	best: 0.4996485 (1098)	total: 1m 29s	remaining: 12m 3s

# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.4980790873
# bestIteration = 2856
#
# Shrink model to first 2857 iterations.
# fold : 3
# 0:	learn: 0.6802626	test: 0.6803626	best: 0.6803626 (0)	total: 191ms	remaining: 31m 49s
# 100:	learn: 0.5094178	test: 0.5151269	best: 0.5151269 (100)	total: 9.27s	remaining: 15m 8s
# 200:	learn: 0.5019519	test: 0.5114621	best: 0.5114522 (199)	total: 17.9s	remaining: 14m 34s
# 300:	learn: 0.4973684	test: 0.5103799	best: 0.5103791 (299)	total: 26.7s	remaining: 14m 19s
# 400:	learn: 0.4932855	test: 0.5096348	best: 0.5096333 (399)	total: 34.6s	remaining: 13m 48s
# 500:	learn: 0.4885077	test: 0.5091304	best: 0.5091276 (499)	total: 42.5s	remaining: 13m 25s
# 600:	learn: 0.4834345	test: 0.5083264	best: 0.5083264 (600)	total: 50.3s	remaining: 13m 6s
# 700:	learn: 0.4790677	test: 0.5079749	best: 0.5079749 (700)	total: 58.4s	remaining: 12m 54s
# 800:	learn: 0.4747417	test: 0.5076935	best: 0.5076645 (758)	total: 1m 6s	remaining: 12m 41s
# 900:	learn: 0.4706621	test: 0.5073364	best: 0.5073253 (891)	total: 1m 14s	remaining: 12m 29s
# 1000:	learn: 0.4669404	test: 0.5070666	best: 0.5070338 (994)	total: 1m 22s	remaining: 12m 18s
# 1100:	learn: 0.4634077	test: 0.5070664	best: 0.5069898 (1022)	total: 1m 29s	remaining: 12m 6s
# 1200:	learn: 0.4600551	test: 0.5072468	best: 0.5069842 (1104)	total: 1m 38s	remaining: 11m 58s
# 1300:	learn: 0.4567769	test: 0.5073342	best: 0.5069842 (1104)	total: 1m 46s	remaining: 11m 49s
# 1400:	learn: 0.4536073	test: 0.5072871	best: 0.5069842 (1104)	total: 1m 54s	remaining: 11m 41s
# 1500:	learn: 0.4506737	test: 0.5072502	best: 0.5069842 (1104)	total: 2m 2s	remaining: 11m 31s
# 1600:	learn: 0.4477011	test: 0.5073147	best: 0.5069842 (1104)	total: 2m 10s	remaining: 11m 22s
# 1700:	learn: 0.4447752	test: 0.5071405	best: 0.5069842 (1104)	total: 2m 17s	remaining: 11m 12s
# 1800:	learn: 0.4419651	test: 0.5070255	best: 0.5069842 (1104)	total: 2m 25s	remaining: 11m 4s
# 1900:	learn: 0.4392143	test: 0.5070231	best: 0.5069837 (1823)	total: 2m 34s	remaining: 10m 56s
# 2000:	learn: 0.4365781	test: 0.5071067	best: 0.5069837 (1823)	total: 2m 41s	remaining: 10m 47s
# 2100:	learn: 0.4340859	test: 0.5071641	best: 0.5069837 (1823)	total: 2m 49s	remaining: 10m 38s
# 2200:	learn: 0.4314580	test: 0.5072476	best: 0.5069837 (1823)	total: 2m 57s	remaining: 10m 30s
# 2300:	learn: 0.4290310	test: 0.5072655	best: 0.5069837 (1823)	total: 3m 5s	remaining: 10m 21s
# 2400:	learn: 0.4266185	test: 0.5072750	best: 0.5069837 (1823)	total: 3m 13s	remaining: 10m 13s
# 2500:	learn: 0.4242893	test: 0.5072627	best: 0.5069837 (1823)	total: 3m 21s	remaining: 10m 5s
# 2600:	learn: 0.4220611	test: 0.5072660	best: 0.5069837 (1823)	total: 3m 29s	remaining: 9m 57s
# 2700:	learn: 0.4197693	test: 0.5072269	best: 0.5069837 (1823)	total: 3m 37s	remaining: 9m 48s
# 2800:	learn: 0.4176042	test: 0.5072952	best: 0.5069837 (1823)	total: 3m 45s	remaining: 9m 40s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.5069836827
# bestIteration = 1823
#
# Shrink model to first 1824 iterations.
# fold : 4
# 0:	learn: 0.6802285	test: 0.6803707	best: 0.6803707 (0)	total: 172ms	remaining: 28m 36s
# 100:	learn: 0.5098320	test: 0.5153456	best: 0.5153456 (100)	total: 8.83s	remaining: 14m 25s
# 200:	learn: 0.5027176	test: 0.5112422	best: 0.5112422 (200)	total: 17.6s	remaining: 14m 17s
# 300:	learn: 0.4984156	test: 0.5097412	best: 0.5097412 (300)	total: 25.9s	remaining: 13m 55s
# 400:	learn: 0.4941327	test: 0.5088537	best: 0.5088455 (399)	total: 34.4s	remaining: 13m 42s
# 500:	learn: 0.4894150	test: 0.5082278	best: 0.5082278 (500)	total: 42.3s	remaining: 13m 22s
# 600:	learn: 0.4848765	test: 0.5077769	best: 0.5077464 (592)	total: 50.2s	remaining: 13m 4s
# 700:	learn: 0.4804971	test: 0.5075156	best: 0.5075108 (690)	total: 58.1s	remaining: 12m 51s
# 800:	learn: 0.4765380	test: 0.5071982	best: 0.5071959 (798)	total: 1m 5s	remaining: 12m 37s
# 900:	learn: 0.4727142	test: 0.5069808	best: 0.5069076 (886)	total: 1m 13s	remaining: 12m 25s
# 1000:	learn: 0.4689753	test: 0.5067001	best: 0.5067001 (1000)	total: 1m 21s	remaining: 12m 15s
# 1100:	learn: 0.4652523	test: 0.5064351	best: 0.5064351 (1100)	total: 1m 29s	remaining: 12m 5s
# 1200:	learn: 0.4617532	test: 0.5061975	best: 0.5061975 (1200)	total: 1m 37s	remaining: 11m 56s
# 1300:	learn: 0.4586099	test: 0.5060068	best: 0.5059616 (1280)	total: 1m 45s	remaining: 11m 47s
# 1400:	learn: 0.4553095	test: 0.5055768	best: 0.5055201 (1387)	total: 1m 53s	remaining: 11m 38s
# 1500:	learn: 0.4522628	test: 0.5053100	best: 0.5053100 (1500)	total: 2m 1s	remaining: 11m 28s
# 1600:	learn: 0.4493700	test: 0.5053240	best: 0.5053100 (1500)	total: 2m 9s	remaining: 11m 19s
# 1700:	learn: 0.4464490	test: 0.5051124	best: 0.5051124 (1700)	total: 2m 17s	remaining: 11m 11s
# 1800:	learn: 0.4436315	test: 0.5049686	best: 0.5049614 (1774)	total: 2m 25s	remaining: 11m 2s
# 1900:	learn: 0.4408804	test: 0.5048654	best: 0.5048161 (1867)	total: 2m 33s	remaining: 10m 54s
# 2000:	learn: 0.4382387	test: 0.5047098	best: 0.5046999 (1998)	total: 2m 41s	remaining: 10m 45s
# 2100:	learn: 0.4357160	test: 0.5046805	best: 0.5046638 (2097)	total: 2m 49s	remaining: 10m 36s
# 2200:	learn: 0.4332578	test: 0.5045726	best: 0.5045682 (2195)	total: 2m 57s	remaining: 10m 28s
# 2300:	learn: 0.4308574	test: 0.5045490	best: 0.5045314 (2278)	total: 3m 5s	remaining: 10m 20s
# 2400:	learn: 0.4284909	test: 0.5044922	best: 0.5044531 (2377)	total: 3m 13s	remaining: 10m 11s
# 2500:	learn: 0.4261679	test: 0.5045446	best: 0.5044453 (2417)	total: 3m 21s	remaining: 10m 3s
# 2600:	learn: 0.4238769	test: 0.5045720	best: 0.5044453 (2417)	total: 3m 29s	remaining: 9m 55s
# 2700:	learn: 0.4217176	test: 0.5046679	best: 0.5044453 (2417)	total: 3m 36s	remaining: 9m 46s
# 2800:	learn: 0.4195147	test: 0.5046778	best: 0.5044453 (2417)	total: 3m 45s	remaining: 9m 38s
# 2900:	learn: 0.4173152	test: 0.5046262	best: 0.5044453 (2417)	total: 3m 52s	remaining: 9m 29s
# 3000:	learn: 0.4152166	test: 0.5046564	best: 0.5044453 (2417)	total: 4m	remaining: 9m 21s
# 3100:	learn: 0.4130472	test: 0.5047462	best: 0.5044453 (2417)	total: 4m 8s	remaining: 9m 13s
# 3200:	learn: 0.4108445	test: 0.5048188	best: 0.5044453 (2417)	total: 4m 16s	remaining: 9m 5s
# 3300:	learn: 0.4087479	test: 0.5047612	best: 0.5044453 (2417)	total: 4m 24s	remaining: 8m 57s
# 3400:	learn: 0.4066570	test: 0.5048345	best: 0.5044453 (2417)	total: 4m 32s	remaining: 8m 49s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.5044453072
# bestIteration = 2417
#
# Shrink model to first 2418 iterations.
# logloss 0.480473
# best_score 0.696686
# best_threshold 0.630
# ------------------------------
# Q1 : F1 = 0.614689
# Q2 : F1 = 0.553341
# Q3 : F1 = 0.572307
# Q4 : F1 = 0.644651
# Q5 : F1 = 0.390560
# Q6 : F1 = 0.613390
# Q7 : F1 = 0.581108
# Q8 : F1 = 0.387753
# Q9 : F1 = 0.590273
# Q10 : F1 = 0.366670
# Q11 : F1 = 0.383266
# Q12 : F1 = 0.591667
# Q13 : F1 = 0.424014
# Q14 : F1 = 0.483068
# Q15 : F1 = 0.379791
# Q16 : F1 = 0.422548
# Q17 : F1 = 0.385756
# Q18 : F1 = 0.527664
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2     valid_train_test_process_identity()
#       3     run_train()
# ----> 4 inference(cfg.mode)
#
# Cell In[17], line 23, in inference(mode)
#      21         models.append(model)
#      22     model_dict[g] = models
# ---> 23     features_dict[g] = list(model.feature_importances_)
#      24 need_create_features = features_dict["0-4"] + features_dict["5-12"] + features_dict["13-22"]
#      25 not_drop_cols = ["0-4_elapsed_time_max", "0-4_index_max", "5-12_elapsed_time_max", "5-12_index_max", "13-22_elapsed_time_max", "13-22_index_max",
#      26                  "0-4_elapsed_time_min", "0-4_index_min", "5-12_elapsed_time_min", "5-12_index_min", "13-22_elapsed_time_min", "13-22_index_min"]
#
# TypeError: iteration over a 0-d array
