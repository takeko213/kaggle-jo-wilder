# %% [markdown]
# # eda012
# click座標

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
import itertools

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
@dataclass
class Cfg:
    exp_name = "eda011"
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")
cfg = Cfg()

# %%
train = pd.read_csv(cfg.input_dir + "train.csv")

# %%
df1 = train[(train["event_name"]=="object_click")&(train["fqid"]=="logbook.page.bingo")]
df2 = train[(train["event_name"]=="object_click")&(train["fqid"]=="logbook")]
plt.scatter(df2["room_coor_x"], df2["room_coor_y"], alpha=0.1)
plt.scatter(df1["room_coor_x"], df1["room_coor_y"], alpha=0.1)

# %%
df1 = train[(train["event_name"]=="object_click")&(train["fqid"]=="tunic.hub.slip")]
df2 = train[(train["event_name"]=="object_click")&(train["fqid"]=="tunic")]
plt.scatter(df2["room_coor_x"], df2["room_coor_y"], alpha=0.1)
plt.scatter(df1["room_coor_x"], df1["room_coor_y"], alpha=0.1)

# %%
df1 = train[(train["event_name"]=="object_click")&(train["fqid"]=="plaque.face.date")]
df2 = train[(train["event_name"]=="object_click")&(train["fqid"]=="plaque")]
plt.scatter(df2["room_coor_x"], df2["room_coor_y"], alpha=0.1)
plt.scatter(df1["room_coor_x"], df1["room_coor_y"], alpha=0.1)

# %%
df1 = train[(train["event_name"]=="object_click")&(train["fqid"]=="businesscards.card_bingo.bingo")]
df2 = train[(train["event_name"]=="object_click")&(train["fqid"]=="businesscards")]
plt.scatter(df2["room_coor_x"], df2["room_coor_y"], alpha=0.1)
plt.scatter(df1["room_coor_x"], df1["room_coor_y"], alpha=0.1)

# %%
df1 = train[(train["event_name"]=="object_click")&(train["fqid"]=="logbook.page.bingo")]
df2 = train[(train["event_name"]=="object_click")&(train["fqid"]=="logbook")]
plt.scatter(df2["room_coor_x"], df2["room_coor_y"], alpha=0.1)
plt.scatter(df1["room_coor_x"], df1["room_coor_y"], alpha=0.1)

# %%
plt.scatter(df2["screen_coor_x"], df2["screen_coor_y"], alpha=0.1)
plt.scatter(df1["screen_coor_x"], df1["screen_coor_y"], alpha=0.1)

# %%
df1["session_id"].value_counts().value_counts()
# Out:
# 1    23438
# 2      121
# 3        3
# Name: session_id, dtype: int64
