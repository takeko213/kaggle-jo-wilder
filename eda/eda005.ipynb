# %% [markdown]
# # eda005

# %% [markdown]
# の特徴量検討

# %%
import os
import sys
import traceback
import gc
import random
import pickle
import pathlib
import subprocess
from dataclasses import dataclass
from dotenv import load_dotenv
load_dotenv
sys.path.append(os.getenv('UTILS_PATH'))
import itertools

import pandas as pd
import numpy as np

# %%
@dataclass
class Cfg:
    exp_name = "eda001"
    input_dir = os.getenv('INPUT_DIR')
    output_dir = os.getenv('OUTPUT_DIR')
    prep_dir = os.getenv("PREP_DIR")
cfg = Cfg()

# %%
train = pd.read_csv(cfg.input_dir + "train.csv")
labels = pd.read_csv(cfg.input_dir + "train_labels.csv")
test = pd.read_csv(cfg.input_dir + "test.csv")
sub = pd.read_csv(cfg.input_dir + "sample_submission.csv")

# %%
train.dropna(subset=["hover_duration"])
# Out:
#                  session_id  index  elapsed_time    event_name       name  \
# 49        20090312431273200     49         52328  object_hover      basic
# 82        20090312431273200     82         87242  object_hover      basic
# 87        20090312431273200     87         92242  object_hover  undefined
# 127       20090312431273200    127        135124     map_hover      basic
# 128       20090312431273200    128        135256     map_hover      basic
# ...                     ...    ...           ...           ...        ...
# 13174191  22100221145014656   1585       5447168  object_hover  undefined
# 13174193  22100221145014656   1587       5448152  object_hover  undefined
# 13174194  22100221145014656   1588       5466868  object_hover  undefined
# 13174203  22100221145014656   1597       5482022     map_hover      basic
# 13174204  22100221145014656   1598       5481765     map_hover      basic
#
#           level  page  room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  \
# 49            1   NaN          NaN          NaN            NaN            NaN
# 82            2   NaN          NaN          NaN            NaN            NaN
# 87            2   NaN          NaN          NaN            NaN            NaN
# 127           3   NaN          NaN          NaN            NaN            NaN
# 128           3   NaN          NaN          NaN            NaN            NaN
# ...         ...   ...          ...          ...            ...            ...
# 13174191     21   NaN          NaN          NaN            NaN            NaN
# 13174193     21   NaN          NaN          NaN            NaN            NaN
# 13174194     21   NaN          NaN          NaN            NaN            NaN
# 13174203     22   NaN          NaN          NaN            NaN            NaN
# 13174204     22   NaN          NaN          NaN            NaN            NaN
#
#           hover_duration text                      fqid  \
# 49                7899.0  NaN                groupconvo
# 82                 400.0  NaN                     tunic
# 87                3949.0  NaN            tunic.hub.slip
# 127                234.0  NaN   tunic.historicalsociety
# 128                 17.0  NaN          tunic.kohlcenter
# ...                  ...  ...                       ...
# 13174191            99.0  NaN  journals_flag.pic_2.next
# 13174193           565.0  NaN  journals_flag.pic_2.next
# 13174194           150.0  NaN  journals_flag.pic_0.next
# 13174203          1200.0  NaN                     tomap
# 13174204            51.0  NaN          tunic.drycleaner
#
#                                    room_fqid text_fqid  fullscreen  hq  music  \
# 49             tunic.historicalsociety.entry       NaN         NaN NaN    NaN
# 82        tunic.historicalsociety.collection       NaN         NaN NaN    NaN
# 87        tunic.historicalsociety.collection       NaN         NaN NaN    NaN
# 127            tunic.historicalsociety.entry       NaN         NaN NaN    NaN
# 128            tunic.historicalsociety.entry       NaN         NaN NaN    NaN
# ...                                      ...       ...         ...  ..    ...
# 13174191      tunic.historicalsociety.stacks       NaN         NaN NaN    NaN
# 13174193      tunic.historicalsociety.stacks       NaN         NaN NaN    NaN
# 13174194      tunic.historicalsociety.stacks       NaN         NaN NaN    NaN
# 13174203       tunic.historicalsociety.entry       NaN         NaN NaN    NaN
# 13174204       tunic.historicalsociety.entry       NaN         NaN NaN    NaN
#
#          level_group
# 49               0-4
# 82               0-4
# 87               0-4
# 127              0-4
# 128              0-4
# ...              ...
# 13174191       13-22
# 13174193       13-22
# 13174194       13-22
# 13174203       13-22
# 13174204       13-22
#
# [1000737 rows x 20 columns]
